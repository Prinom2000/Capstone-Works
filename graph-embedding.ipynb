# %%
# !pip install karateclub
# Out:
# Collecting karateclub
#   Downloading karateclub-1.3.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 kB 760.9 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting numpy<1.23.0 (from karateclub)
#   Downloading numpy-1.22.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting networkx<2.7 (from karateclub)
#   Downloading networkx-2.6.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting decorator==4.4.2 (from karateclub)
#   Downloading decorator-4.4.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from karateclub) (4.66.4)
# Requirement already satisfied: python-louvain in /opt/conda/lib/python3.10/site-packages (from karateclub) (0.16)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from karateclub) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from karateclub) (1.11.4)
# Collecting pygsp (from karateclub)
#   Downloading PyGSP-0.5.1-py2.py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: gensim>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from karateclub) (4.3.2)
# Collecting pandas<=1.3.5 (from karateclub)
#   Downloading pandas-1.3.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from karateclub) (1.16.0)
# Collecting python-Levenshtein (from karateclub)
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim>=4.0.0->karateclub) (6.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.10/site-packages (from pandas<=1.3.5->karateclub) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.10/site-packages (from pandas<=1.3.5->karateclub) (2023.3.post1)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein->karateclub)
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein->karateclub)
#   Downloading rapidfuzz-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->karateclub) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->karateclub) (3.2.0)
# Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.22.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 59.9 MB/s eta 0:00:00:00:0100:01
# Downloading pandas-1.3.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 68.4 MB/s eta 0:00:00:00:010:01
# Downloading PyGSP-0.5.1-py2.py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.1 MB/s eta 0:00:00
# Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 15.9 MB/s eta 0:00:00
# Downloading rapidfuzz-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 77.2 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: karateclub
#   Building wheel for karateclub (setup.py) ... done
#   Created wheel for karateclub: filename=karateclub-1.3.3-py3-none-any.whl size=101982 sha256=2d12d6303b1b59cad07208933ece13d07e95f059e0e3d77b44442a637b9fd6b8
#   Stored in directory: /root/.cache/pip/wheels/62/bd/af/17e7ca6ba0ed144d22502780f5c0660a8e4985939dc6973a81
# Successfully built karateclub
# Installing collected packages: rapidfuzz, numpy, networkx, decorator, pandas, Levenshtein, python-Levenshtein, pygsp, karateclub
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.4.1 requires cubinlinker, which is not installed.
# cudf 24.4.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.4.1 requires ptxcompiler, which is not installed.
# cuml 24.4.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.4.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-nlp 0.12.1 requires keras-core, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# albumentations 1.4.0 requires numpy>=1.24.4, but you have numpy 1.22.4 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 14.0.2 which is incompatible.
# arviz 0.18.0 requires numpy<2.0,>=1.23.0, but you have numpy 1.22.4 which is incompatible.
# arviz 0.18.0 requires pandas>=1.5.0, but you have pandas 1.3.5 which is incompatible.
# astropy 6.1.0 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.1 which is incompatible.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.22.4 which is incompatible.
# cudf 24.4.1 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.5.0 which is incompatible.
# cudf 24.4.1 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# cudf 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.3.5 which is incompatible.
# dask-cuda 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# dask-cudf 24.4.1 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# dask-cudf 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.3.5 which is incompatible.
# dask-expr 1.1.2 requires pandas>=2, but you have pandas 1.3.5 which is incompatible.
# esda 2.5.1 requires pandas>1.4, but you have pandas 1.3.5 which is incompatible.
# featuretools 1.31.0 requires numpy>=1.25.0, but you have numpy 1.22.4 which is incompatible.
# featuretools 1.31.0 requires pandas>=2.0.0, but you have pandas 1.3.5 which is incompatible.
# geopandas 0.14.4 requires pandas>=1.4.0, but you have pandas 1.3.5 which is incompatible.
# inequality 1.0.1 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires pandas>=1.4, but you have pandas 1.3.5 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# mapclassify 2.6.1 requires networkx>=2.7, but you have networkx 2.6.3 which is incompatible.
# mapclassify 2.6.1 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# mapclassify 2.6.1 requires pandas!=1.5.0,>=1.4, but you have pandas 1.3.5 which is incompatible.
# mizani 0.11.4 requires numpy>=1.23.0, but you have numpy 1.22.4 which is incompatible.
# mizani 0.11.4 requires pandas>=2.1.0, but you have pandas 1.3.5 which is incompatible.
# momepy 0.7.0 requires networkx>=2.7, but you have networkx 2.6.3 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.3 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# plotnine 0.13.6 requires numpy>=1.23.0, but you have numpy 1.22.4 which is incompatible.
# plotnine 0.13.6 requires pandas<3.0.0,>=2.1.0, but you have pandas 1.3.5 which is incompatible.
# pyldavis 3.4.1 requires numpy>=1.24.2, but you have numpy 1.22.4 which is incompatible.
# pyldavis 3.4.1 requires pandas>=2.0.0, but you have pandas 1.3.5 which is incompatible.
# pylibraft 24.4.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.5.0 which is incompatible.
# pylibraft 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# raft-dask 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# rapids-dask-dependency 24.4.1a0 requires dask==2024.1.1, but you have dask 2024.5.2 which is incompatible.
# rapids-dask-dependency 24.4.1a0 requires dask-expr==0.4.0, but you have dask-expr 1.1.2 which is incompatible.
# rmm 24.4.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.5.0 which is incompatible.
# rmm 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# scikit-image 0.22.0 requires networkx>=2.8, but you have networkx 2.6.3 which is incompatible.
# spaghetti 1.7.5.post1 requires pandas!=1.5.0,>=1.4, but you have pandas 1.3.5 which is incompatible.
# spglm 1.1.0 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# spopt 0.6.0 requires networkx>=2.7, but you have networkx 2.6.3 which is incompatible.
# spopt 0.6.0 requires pandas!=1.5.0,>=1.4, but you have pandas 1.3.5 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# spreg 1.4.2 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# tensorflow 2.15.0 requires keras<2.16,>=2.15.0, but you have keras 3.3.3 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 1.22.4 which is incompatible.
# tensorstore 0.1.60 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# ucx-py 0.37.0 requires numpy<2.0a0,>=1.23, but you have numpy 1.22.4 which is incompatible.
# woodwork 0.31.0 requires numpy>=1.25.0, but you have numpy 1.22.4 which is incompatible.
# woodwork 0.31.0 requires pandas>=2.0.0, but you have pandas 1.3.5 which is incompatible.
# xarray 2024.5.0 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# xarray 2024.5.0 requires packaging>=23.1, but you have packaging 21.3 which is incompatible.
# xarray 2024.5.0 requires pandas>=2.0, but you have pandas 1.3.5 which is incompatible.
# Successfully installed Levenshtein-0.25.1 decorator-4.4.2 karateclub-1.3.3 networkx-2.6.3 numpy-1.22.4 pandas-1.3.5 pygsp-0.5.1 python-Levenshtein-0.25.1 rapidfuzz-3.9.3

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from karateclub.node_embedding.neighbourhood.deepwalk import DeepWalk

# %%
G=nx.random_tree (40)
nx.draw_spring (G)
plt.show()

# %% [markdown]
# # 2D

# %%
# Apply DeepWalk embedding
model = DeepWalk(dimensions=2)
model.fit(G)
embedding = model.get_embedding()

plt.scatter(embedding[:,0], embedding[:,1])

# %%
print(embedding)
# Out:
# [[ 2.4367876   1.039869  ]
#  [ 2.5194197  -1.2673625 ]
#  [ 1.2774758  -0.11861505]
#  [ 3.9433477   1.4924183 ]
#  [ 1.1090611  -0.19072244]
#  [ 3.197335    1.112916  ]
#  [-0.3508747  -4.795709  ]
#  [ 0.10595628 -2.2213624 ]
#  [ 1.0380923  -0.19783264]
#  [ 2.6899543   1.1316546 ]
#  [ 0.3909646  -2.1878755 ]
#  [ 3.1529138   1.053792  ]
#  [-0.45028988 -5.198492  ]
#  [-0.6160848  -3.5903075 ]
#  [ 0.804932   -0.74269176]
#  [-0.22067632 -1.8715756 ]
#  [-0.15127045 -4.119594  ]
#  [ 0.570472   -0.11918218]
#  [ 3.8523114   1.3223497 ]
#  [ 1.8528284  -1.5871567 ]
#  [ 1.4843538  -1.3382621 ]
#  [ 0.40767807 -1.3838259 ]
#  [ 0.77054834 -1.6691259 ]
#  [ 1.6629211  -1.3664372 ]
#  [ 1.0489347  -0.25461543]
#  [ 2.4068413   1.2242079 ]
#  [ 1.3663616  -1.5784488 ]
#  [ 5.0705576   1.8541843 ]
#  [ 0.43035266 -0.8719419 ]
#  [ 1.1732565  -0.47043902]
#  [-0.8178754  -4.7044287 ]
#  [ 0.34292388 -1.6318662 ]
#  [-0.37776643 -4.272816  ]
#  [ 1.4292357  -0.441217  ]
#  [ 4.768217    1.4837418 ]
#  [-0.10572516 -1.7840501 ]
#  [ 3.8540444   1.1936667 ]
#  [ 0.9045061  -1.4505755 ]
#  [ 2.1793354  -1.6580606 ]
#  [ 0.88423437 -0.68958986]]

# %% [markdown]
# # 3D

# %%
# Apply DeepWalk embedding
model = DeepWalk(dimensions=3)
model.fit(G)
embedding = model.get_embedding()

fig= plt.figure(figsize=(15,8))
ax=fig.add_subplot(projection= "3d")
ax.scatter(embedding[:,0], embedding[:,1], embedding[:,2])

# %%
print(embedding)
# Out:
# [[ 1.7022332   0.47529596 -3.061852  ]
#  [ 3.3083205   0.5517072   2.90227   ]
#  [ 1.911229    1.0917711  -4.5934615 ]
#  [ 3.066763    1.5003102  -2.8229923 ]
#  [ 1.927636    0.9710273  -3.9371252 ]
#  [ 3.6172328   2.3382661   0.35551178]
#  [ 2.1158135  -4.2598224   2.7454917 ]
#  [ 1.283731   -2.3613844   1.1868998 ]
#  [ 0.9967035   0.17727977 -3.5871556 ]
#  [ 1.947617    1.1007069  -1.9955437 ]
#  [-0.05481463 -4.231042   -0.72655904]
#  [ 4.0745893   2.105365    0.68769324]
#  [ 2.3059537  -4.4478683   3.2085004 ]
#  [ 0.28533912 -3.4740753  -4.459257  ]
#  [ 0.15281656 -2.4986913  -0.90512305]
#  [ 0.01256137 -2.3201137  -3.927184  ]
#  [ 1.8681725  -3.9786465   2.6364503 ]
#  [ 0.33435383 -1.2660334  -1.5069945 ]
#  [ 3.8777134   2.1741574  -0.6029899 ]
#  [ 4.4940224   0.02726164  2.7286441 ]
#  [ 3.4793608  -0.21563381  2.7852902 ]
#  [ 0.20868853 -3.9773874  -0.79375136]
#  [ 1.2638953  -2.4806635   0.23597725]
#  [ 2.334621   -0.5518128   2.2709336 ]
#  [ 0.80228394 -1.0768821  -3.1786249 ]
#  [ 2.4727519   1.2990172   0.17822339]
#  [ 3.69843    -0.84392315  3.1727982 ]
#  [ 3.4017587   1.3835145  -3.1223245 ]
#  [ 0.6689065  -0.7537879  -3.308018  ]
#  [ 1.1362365  -0.5608839   0.39963287]
#  [ 0.26550275 -3.2497907  -4.490738  ]
#  [ 1.03734    -2.3096962   0.3338927 ]
#  [ 1.6913079  -3.8209298   2.3837352 ]
#  [ 1.5985144  -0.7725369   0.19447868]
#  [ 3.4560885   2.0884724  -0.08639845]
#  [ 1.4774787  -2.5584908   0.00828858]
#  [ 2.7491183   1.1128111  -2.7497888 ]
#  [ 1.7970091  -0.4940558   2.0040264 ]
#  [ 4.3482575   0.40807393  3.330603  ]
#  [ 0.25846443 -1.8955301  -0.7368815 ]]

# %% [markdown]
# # 50D

# %%
# Apply DeepWalk embedding
model = DeepWalk(dimensions=50)
model.fit(G)
embedding = model.get_embedding()
print(embedding)
# Out:
# [[ 0.47898912  0.1975546  -0.7168327  ...  0.307371   -0.86999077
#   -0.5945765 ]
#  [ 0.70978534 -0.39850044 -1.3625114  ... -0.01697012  0.04083251
#   -0.3140016 ]
#  [ 0.7545594  -0.22229742 -0.31797853 ...  0.8768394  -0.08810209
#   -0.9271337 ]
#  ...
#  [-0.2466384   0.4590668   0.14295216 ...  0.18200287 -0.29592362
#    0.31966624]
#  [ 0.5810266  -0.2795383  -1.2149419  ...  0.27064982 -0.21255022
#   -0.34656525]
#  [-0.786302    0.05458304  0.5178529  ...  0.55112475 -0.7034138
#    0.40550432]]
