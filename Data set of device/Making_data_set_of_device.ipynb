# %%
# !pip install SPARQLWrapper
# Out:
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting rdflib>=6.1.1 (from SPARQLWrapper)
#   Downloading rdflib-7.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting isodate<1.0.0,>=0.7.2 (from rdflib>=6.1.1->SPARQLWrapper)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.2.0)
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Downloading rdflib-7.1.1-py3-none-any.whl (562 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.4/562.4 kB 10.4 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 isodate-0.7.2 rdflib-7.1.1

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")

# Adjusted SPARQL query
sparql.setQuery("""
    SELECT ?device ?name ?manufacturer ?releaseDate
    WHERE {
        # ?device a dbo:Device .
        # ?device foaf:name ?name .
        OPTIONAL { ?device dbo:manufacturer ?manufacturer . }
        OPTIONAL { ?device dbo:releaseDate ?releaseDate . }
        FILTER (lang(?name) = 'en')
    }
    LIMIT 100
""")

sparql.setReturnFormat(JSON)

try:
    results = sparql.query().convert()
    # Process results
    data = []
    for result in results["results"]["bindings"]:
        data.append({
            "Device": result["device"]["value"],
            "Name": result["name"]["value"],
            "Manufacturer": result.get("manufacturer", {}).get("value"),
            "Release Date": result.get("releaseDate", {}).get("value"),
        })

    df = pd.DataFrame(data)
    df.to_csv("electronic_devices_fixed.csv", index=False)
    print("Dataset saved as electronic_devices_fixed.csv")
    print(df.head())
except Exception as e:
    print(f"Error: {e}")
# Out:
# Dataset saved as electronic_devices_fixed.csv
#                                               Device  \
# 0  http://dbpedia.org/resource/Casio_G'zOne_Commando
# 1         http://dbpedia.org/resource/Royole_FlexPai
# 2      http://dbpedia.org/resource/Samsung_Continuum
# 3  http://dbpedia.org/resource/Samsung_Galaxy_(or...
# 4     http://dbpedia.org/resource/Samsung_Galaxy_A01
#
#                                    Name  \
# 0                 Casio G'zOne Commando
# 1                        Royole FlexPai
# 2                Samsung Continuum i400
# 3  Samsung Galaxy (GT-I7500, GT-I7500L)
# 4                    Samsung Galaxy A01
#
#                                         Manufacturer Release Date
# 0  http://dbpedia.org/resource/NEC_Casio_Mobile_C...   2011-04-28
# 1                 http://dbpedia.org/resource/Royole   2018-01-08
# 2    http://dbpedia.org/resource/Samsung_Electronics   2010-06-04
# 3                http://dbpedia.org/resource/Samsung   2009-06-29
# 4    http://dbpedia.org/resource/Samsung_Electronics   2020-01-24

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# Set up the SPARQL endpoint
sparql = SPARQLWrapper("http://dbpedia.org/sparql")

# Initialize an empty list to store data
data = []

# Define query parameters
rows_per_query = 100  # Number of rows to fetch per query
total_records = 1000  # Target total number of records

for offset in range(0, total_records, rows_per_query):
    # SPARQL query with pagination
    sparql.setQuery(f"""
        SELECT ?device ?name ?manufacturer ?releaseDate
        WHERE {{
            # ?device a dbo:Device .
            # ?device foaf:name ?name .
            OPTIONAL {{ ?device dbo:manufacturer ?manufacturer . }}
            OPTIONAL {{ ?device dbo:releaseDate ?releaseDate . }}
            FILTER (lang(?name) = 'en')
        }}
        LIMIT {rows_per_query} OFFSET {offset}
    """)
    sparql.setReturnFormat(JSON)

    try:
        # Execute the query
        results = sparql.query().convert()
        for result in results["results"]["bindings"]:
            # Append data to the list
            data.append({
                "Device": result["device"]["value"],
                "Name": result["name"]["value"],
                "Manufacturer": result.get("manufacturer", {}).get("value"),
                "Release Date": result.get("releaseDate", {}).get("value"),
            })
    except Exception as e:
        print(f"Error occurred for offset {offset}: {e}")
        break

# Convert the collected data to a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv("electronic_devices_1000.csv", index=False)
print("Dataset saved as electronic_devices_1000.csv")

# Display the first few rows
print(df.head())
# Out:
# Dataset saved as electronic_devices_1000.csv
#                                               Device  \
# 0  http://dbpedia.org/resource/Casio_G'zOne_Commando
# 1         http://dbpedia.org/resource/Royole_FlexPai
# 2      http://dbpedia.org/resource/Samsung_Continuum
# 3  http://dbpedia.org/resource/Samsung_Galaxy_(or...
# 4     http://dbpedia.org/resource/Samsung_Galaxy_A01
#
#                                    Name  \
# 0                 Casio G'zOne Commando
# 1                        Royole FlexPai
# 2                Samsung Continuum i400
# 3  Samsung Galaxy (GT-I7500, GT-I7500L)
# 4                    Samsung Galaxy A01
#
#                                         Manufacturer Release Date
# 0  http://dbpedia.org/resource/NEC_Casio_Mobile_C...   2011-04-28
# 1                 http://dbpedia.org/resource/Royole   2018-01-08
# 2    http://dbpedia.org/resource/Samsung_Electronics   2010-06-04
# 3                http://dbpedia.org/resource/Samsung   2009-06-29
# 4    http://dbpedia.org/resource/Samsung_Electronics   2020-01-24

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import time  # To add delay if needed to avoid overloading the endpoint

# Set up the SPARQL endpoint
sparql = SPARQLWrapper("http://dbpedia.org/sparql")

# Initialize an empty list to store data
data = []

# Define query parameters
rows_per_query = 500  # Number of rows to fetch per query
total_records = 10000  # Target total number of records

for offset in range(0, total_records, rows_per_query):
    print(f"Fetching rows {offset + 1} to {offset + rows_per_query}...")

    # SPARQL query with pagination
    sparql.setQuery(f"""
        SELECT ?device ?name ?manufacturer ?releaseDate
        WHERE {{
            # ?device a dbo:Device .
            # ?device foaf:name ?name .
            OPTIONAL {{ ?device dbo:manufacturer ?manufacturer . }}
            OPTIONAL {{ ?device dbo:releaseDate ?releaseDate . }}
            FILTER (lang(?name) = 'en')
        }}
        LIMIT {rows_per_query} OFFSET {offset}
    """)
    sparql.setReturnFormat(JSON)

    try:
        # Execute the query
        results = sparql.query().convert()
        for result in results["results"]["bindings"]:
            # Append data to the list
            data.append({
                "Device": result["device"]["value"],
                "Name": result["name"]["value"],
                "Manufacturer": result.get("manufacturer", {}).get("value"),
                "Release Date": result.get("releaseDate", {}).get("value"),
            })

        # Add a small delay to avoid overloading the endpoint
        time.sleep(1)  # Optional: Adjust if you experience rate-limiting issues
    except Exception as e:
        print(f"Error occurred for offset {offset}: {e}")
        break

# Convert the collected data to a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv("electronic_devices_10000.csv", index=False)
print("Dataset saved as electronic_devices_10000.csv")

# Display the first few rows
print(df.head())
# Out:
# Fetching rows 1 to 500...
# Fetching rows 501 to 1000...
# Fetching rows 1001 to 1500...
# Fetching rows 1501 to 2000...
# Fetching rows 2001 to 2500...
# Fetching rows 2501 to 3000...
# Fetching rows 3001 to 3500...
# Fetching rows 3501 to 4000...
# Fetching rows 4001 to 4500...
# Fetching rows 4501 to 5000...
# Fetching rows 5001 to 5500...
# Fetching rows 5501 to 6000...
# Fetching rows 6001 to 6500...
# Fetching rows 6501 to 7000...
# Fetching rows 7001 to 7500...
# Fetching rows 7501 to 8000...
# Fetching rows 8001 to 8500...
# Fetching rows 8501 to 9000...
# Fetching rows 9001 to 9500...
# Fetching rows 9501 to 10000...
# Dataset saved as electronic_devices_10000.csv
#                                               Device  \
# 0  http://dbpedia.org/resource/Casio_G'zOne_Commando
# 1         http://dbpedia.org/resource/Royole_FlexPai
# 2      http://dbpedia.org/resource/Samsung_Continuum
# 3  http://dbpedia.org/resource/Samsung_Galaxy_(or...
# 4     http://dbpedia.org/resource/Samsung_Galaxy_A01
#
#                                    Name  \
# 0                 Casio G'zOne Commando
# 1                        Royole FlexPai
# 2                Samsung Continuum i400
# 3  Samsung Galaxy (GT-I7500, GT-I7500L)
# 4                    Samsung Galaxy A01
#
#                                         Manufacturer Release Date
# 0  http://dbpedia.org/resource/NEC_Casio_Mobile_C...   2011-04-28
# 1                 http://dbpedia.org/resource/Royole   2018-01-08
# 2    http://dbpedia.org/resource/Samsung_Electronics   2010-06-04
# 3                http://dbpedia.org/resource/Samsung   2009-06-29
# 4    http://dbpedia.org/resource/Samsung_Electronics   2020-01-24

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import time

# Set up the SPARQL endpoint
sparql = SPARQLWrapper("http://dbpedia.org/sparql")

# Initialize an empty list to store data
data = []

# Define query parameters
rows_per_query = 500  # Number of rows to fetch per query
total_records = 1000000  # Target total number of records
retry_delay = 5  # Seconds to wait before retrying a failed query

for offset in range(0, total_records, rows_per_query):
    print(f"Fetching rows {offset + 1} to {offset + rows_per_query}...")

    # SPARQL query with pagination
    sparql.setQuery(f"""
        SELECT ?device ?name ?manufacturer ?releaseDate
        WHERE {{
            # ?device a dbo:Device .
            # ?device foaf:name ?name .
            OPTIONAL {{ ?device dbo:manufacturer ?manufacturer . }}
            OPTIONAL {{ ?device dbo:releaseDate ?releaseDate . }}
            FILTER (lang(?name) = 'en')
        }}
        LIMIT {rows_per_query} OFFSET {offset}
    """)
    sparql.setReturnFormat(JSON)

    success = False
    retries = 3  # Number of retries for each query

    while not success and retries > 0:
        try:
            # Execute the query
            results = sparql.query().convert()
            for result in results["results"]["bindings"]:
                # Append data to the list
                data.append({
                    "Device": result["device"]["value"],
                    "Name": result["name"]["value"],
                    "Manufacturer": result.get("manufacturer", {}).get("value"),
                    "Release Date": result.get("releaseDate", {}).get("value"),
                })
            success = True
        except Exception as e:
            print(f"Error occurred for offset {offset}: {e}")
            retries -= 1
            if retries > 0:
                print(f"Retrying in {retry_delay} seconds...")
                time.sleep(retry_delay)
            else:
                print("Skipping this batch after multiple failed attempts.")

    # Optional: Save intermediate results periodically to avoid data loss
    if offset % 10000 == 0 and offset > 0:
        df_partial = pd.DataFrame(data)
        df_partial.to_csv(f"electronic_devices_partial_{offset}.csv", index=False)
        print(f"Saved intermediate dataset up to offset {offset}.")

    # Add a small delay to avoid overloading the endpoint
    time.sleep(1)  # Optional: Adjust this delay if rate limits occur

# Convert the collected data to a DataFrame
df = pd.DataFrame(data)

# Save the complete dataset to a CSV file
df.to_csv("electronic_devices_1M.csv", index=False)
print("Dataset saved as electronic_devices_1M.csv")

# Display the first few rows
print(df.head())
# Out:
# Fetching rows 1 to 500...
# Fetching rows 501 to 1000...
# Fetching rows 1001 to 1500...
# Fetching rows 1501 to 2000...
# Fetching rows 2001 to 2500...
# Fetching rows 2501 to 3000...
# Fetching rows 3001 to 3500...
# Fetching rows 3501 to 4000...
# Fetching rows 4001 to 4500...
# Fetching rows 4501 to 5000...
# Fetching rows 5001 to 5500...
# Fetching rows 5501 to 6000...
# Fetching rows 6001 to 6500...
# Fetching rows 6501 to 7000...
# Fetching rows 7001 to 7500...
# Fetching rows 7501 to 8000...
# Fetching rows 8001 to 8500...
# Fetching rows 8501 to 9000...
# Fetching rows 9001 to 9500...
# Fetching rows 9501 to 10000...
# Fetching rows 10001 to 10500...
# Saved intermediate dataset up to offset 10000.
# Fetching rows 10501 to 11000...
# Fetching rows 11001 to 11500...
# Fetching rows 11501 to 12000...
# Fetching rows 12001 to 12500...
# Fetching rows 12501 to 13000...
# Fetching rows 13001 to 13500...
# Fetching rows 13501 to 14000...
# Fetching rows 14001 to 14500...
# Fetching rows 14501 to 15000...
# Fetching rows 15001 to 15500...
# Fetching rows 15501 to 16000...
# Fetching rows 16001 to 16500...
# Fetching rows 16501 to 17000...
# Fetching rows 17001 to 17500...
# Fetching rows 17501 to 18000...
# Fetching rows 18001 to 18500...
# Fetching rows 18501 to 19000...
# Fetching rows 19001 to 19500...
# Fetching rows 19501 to 20000...
# Fetching rows 20001 to 20500...
# Saved intermediate dataset up to offset 20000.
# Fetching rows 20501 to 21000...
# Fetching rows 21001 to 21500...
# Fetching rows 21501 to 22000...
# Fetching rows 22001 to 22500...
# Fetching rows 22501 to 23000...
# Fetching rows 23001 to 23500...
# Fetching rows 23501 to 24000...
# Fetching rows 24001 to 24500...
# Fetching rows 24501 to 25000...
# Fetching rows 25001 to 25500...
# Fetching rows 25501 to 26000...
# Fetching rows 26001 to 26500...
# Fetching rows 26501 to 27000...
# Fetching rows 27001 to 27500...
# Fetching rows 27501 to 28000...
# Fetching rows 28001 to 28500...
# Fetching rows 28501 to 29000...
# Fetching rows 29001 to 29500...
# Fetching rows 29501 to 30000...
# Fetching rows 30001 to 30500...
# Saved intermediate dataset up to offset 30000.
# Fetching rows 30501 to 31000...
# Fetching rows 31001 to 31500...
# Fetching rows 31501 to 32000...
# Fetching rows 32001 to 32500...
# Fetching rows 32501 to 33000...
# Fetching rows 33001 to 33500...
# Fetching rows 33501 to 34000...
# Fetching rows 34001 to 34500...
# Fetching rows 34501 to 35000...
# Fetching rows 35001 to 35500...
# Fetching rows 35501 to 36000...
# Fetching rows 36001 to 36500...
# Fetching rows 36501 to 37000...
# Fetching rows 37001 to 37500...
# Fetching rows 37501 to 38000...
# Fetching rows 38001 to 38500...
# Fetching rows 38501 to 39000...
# Fetching rows 39001 to 39500...
# Fetching rows 39501 to 40000...
# Fetching rows 40001 to 40500...
# Saved intermediate dataset up to offset 40000.
# Fetching rows 40501 to 41000...
# Fetching rows 41001 to 41500...
# Fetching rows 41501 to 42000...
# Fetching rows 42001 to 42500...
# Fetching rows 42501 to 43000...
# Fetching rows 43001 to 43500...
# Fetching rows 43501 to 44000...
# Fetching rows 44001 to 44500...
# Fetching rows 44501 to 45000...
# Fetching rows 45001 to 45500...
# Fetching rows 45501 to 46000...
# Fetching rows 46001 to 46500...
# Fetching rows 46501 to 47000...
# Fetching rows 47001 to 47500...
# Fetching rows 47501 to 48000...
# Fetching rows 48001 to 48500...
# Fetching rows 48501 to 49000...
# Fetching rows 49001 to 49500...
# Fetching rows 49501 to 50000...
# Fetching rows 50001 to 50500...
# Saved intermediate dataset up to offset 50000.
# Fetching rows 50501 to 51000...
# Fetching rows 51001 to 51500...
# Fetching rows 51501 to 52000...
# Fetching rows 52001 to 52500...
# Fetching rows 52501 to 53000...
# Fetching rows 53001 to 53500...
# Fetching rows 53501 to 54000...
# Fetching rows 54001 to 54500...
# Fetching rows 54501 to 55000...
# Fetching rows 55001 to 55500...
# Fetching rows 55501 to 56000...
# Fetching rows 56001 to 56500...
# Fetching rows 56501 to 57000...
# Fetching rows 57001 to 57500...
# Fetching rows 57501 to 58000...
# Fetching rows 58001 to 58500...
# Fetching rows 58501 to 59000...
# Fetching rows 59001 to 59500...
# Fetching rows 59501 to 60000...
# Fetching rows 60001 to 60500...
# Saved intermediate dataset up to offset 60000.
# Fetching rows 60501 to 61000...
# Fetching rows 61001 to 61500...
# Fetching rows 61501 to 62000...
# Fetching rows 62001 to 62500...
# Fetching rows 62501 to 63000...
# Fetching rows 63001 to 63500...
# Fetching rows 63501 to 64000...
# Fetching rows 64001 to 64500...
# Fetching rows 64501 to 65000...
# Fetching rows 65001 to 65500...
# Fetching rows 65501 to 66000...
# Fetching rows 66001 to 66500...
# Fetching rows 66501 to 67000...
# Fetching rows 67001 to 67500...
# Fetching rows 67501 to 68000...
# Fetching rows 68001 to 68500...
# Fetching rows 68501 to 69000...
# Fetching rows 69001 to 69500...
# Fetching rows 69501 to 70000...
# Fetching rows 70001 to 70500...
# Saved intermediate dataset up to offset 70000.
# Fetching rows 70501 to 71000...
# Fetching rows 71001 to 71500...
# Fetching rows 71501 to 72000...
# Fetching rows 72001 to 72500...
# Fetching rows 72501 to 73000...
# Fetching rows 73001 to 73500...
# Fetching rows 73501 to 74000...
# Fetching rows 74001 to 74500...
# Fetching rows 74501 to 75000...
# Fetching rows 75001 to 75500...
# Fetching rows 75501 to 76000...
# Fetching rows 76001 to 76500...
# Fetching rows 76501 to 77000...
# Fetching rows 77001 to 77500...
# Fetching rows 77501 to 78000...
# Fetching rows 78001 to 78500...
# Fetching rows 78501 to 79000...
# Fetching rows 79001 to 79500...
# Fetching rows 79501 to 80000...
# Fetching rows 80001 to 80500...
# Saved intermediate dataset up to offset 80000.
# Fetching rows 80501 to 81000...
# Fetching rows 81001 to 81500...
# Fetching rows 81501 to 82000...
# Fetching rows 82001 to 82500...
# Fetching rows 82501 to 83000...
# Fetching rows 83001 to 83500...
# Fetching rows 83501 to 84000...
# Fetching rows 84001 to 84500...
# Fetching rows 84501 to 85000...
# Fetching rows 85001 to 85500...
# Fetching rows 85501 to 86000...
# Fetching rows 86001 to 86500...
# Fetching rows 86501 to 87000...
# Fetching rows 87001 to 87500...
# Fetching rows 87501 to 88000...
# Fetching rows 88001 to 88500...
# Fetching rows 88501 to 89000...
# Fetching rows 89001 to 89500...
# Fetching rows 89501 to 90000...
# Fetching rows 90001 to 90500...
# Saved intermediate dataset up to offset 90000.
# Fetching rows 90501 to 91000...
# Fetching rows 91001 to 91500...
# Fetching rows 91501 to 92000...
# Fetching rows 92001 to 92500...
# Fetching rows 92501 to 93000...
# Fetching rows 93001 to 93500...
# Fetching rows 93501 to 94000...
# Fetching rows 94001 to 94500...
# Fetching rows 94501 to 95000...
# Fetching rows 95001 to 95500...
# Fetching rows 95501 to 96000...
# Fetching rows 96001 to 96500...
# Fetching rows 96501 to 97000...
# Fetching rows 97001 to 97500...
# Fetching rows 97501 to 98000...
# Fetching rows 98001 to 98500...
# Fetching rows 98501 to 99000...
# Fetching rows 99001 to 99500...
# Fetching rows 99501 to 100000...
# Fetching rows 100001 to 100500...
# Saved intermediate dataset up to offset 100000.
# Fetching rows 100501 to 101000...
# Fetching rows 101001 to 101500...
# Fetching rows 101501 to 102000...
# Fetching rows 102001 to 102500...
# Fetching rows 102501 to 103000...
# Fetching rows 103001 to 103500...
# Fetching rows 103501 to 104000...
# Fetching rows 104001 to 104500...
# Fetching rows 104501 to 105000...
# Fetching rows 105001 to 105500...
# Fetching rows 105501 to 106000...
# Fetching rows 106001 to 106500...
# Fetching rows 106501 to 107000...
# Fetching rows 107001 to 107500...
# Fetching rows 107501 to 108000...
# Fetching rows 108001 to 108500...
# Fetching rows 108501 to 109000...
# Fetching rows 109001 to 109500...
# Fetching rows 109501 to 110000...
# Fetching rows 110001 to 110500...
# Saved intermediate dataset up to offset 110000.
# Fetching rows 110501 to 111000...
# Fetching rows 111001 to 111500...
# Fetching rows 111501 to 112000...
# Fetching rows 112001 to 112500...
# Fetching rows 112501 to 113000...
# Fetching rows 113001 to 113500...
# Fetching rows 113501 to 114000...
# Fetching rows 114001 to 114500...
# Fetching rows 114501 to 115000...
# Fetching rows 115001 to 115500...
# Fetching rows 115501 to 116000...
# Fetching rows 116001 to 116500...
# Fetching rows 116501 to 117000...
# Fetching rows 117001 to 117500...
# Fetching rows 117501 to 118000...
# Fetching rows 118001 to 118500...
# Fetching rows 118501 to 119000...
# Fetching rows 119001 to 119500...
# Fetching rows 119501 to 120000...
# Fetching rows 120001 to 120500...
# Saved intermediate dataset up to offset 120000.
# Fetching rows 120501 to 121000...
# Fetching rows 121001 to 121500...
# Fetching rows 121501 to 122000...
# Fetching rows 122001 to 122500...
# Fetching rows 122501 to 123000...
# Fetching rows 123001 to 123500...
# Fetching rows 123501 to 124000...
# Fetching rows 124001 to 124500...
# Fetching rows 124501 to 125000...
# Fetching rows 125001 to 125500...
# Fetching rows 125501 to 126000...
# Fetching rows 126001 to 126500...
# Fetching rows 126501 to 127000...
# Fetching rows 127001 to 127500...
# Fetching rows 127501 to 128000...
# Fetching rows 128001 to 128500...
# Fetching rows 128501 to 129000...
# Fetching rows 129001 to 129500...
# Fetching rows 129501 to 130000...
# Fetching rows 130001 to 130500...
# Saved intermediate dataset up to offset 130000.
# Fetching rows 130501 to 131000...
# Fetching rows 131001 to 131500...
# Fetching rows 131501 to 132000...
# Fetching rows 132001 to 132500...
# Fetching rows 132501 to 133000...
# Fetching rows 133001 to 133500...
# Fetching rows 133501 to 134000...
# Fetching rows 134001 to 134500...
# Fetching rows 134501 to 135000...
# Fetching rows 135001 to 135500...
# Fetching rows 135501 to 136000...
# Fetching rows 136001 to 136500...
# Fetching rows 136501 to 137000...
# Fetching rows 137001 to 137500...
# Fetching rows 137501 to 138000...
# Fetching rows 138001 to 138500...
# Fetching rows 138501 to 139000...
# Fetching rows 139001 to 139500...
# Fetching rows 139501 to 140000...
# Fetching rows 140001 to 140500...
# Saved intermediate dataset up to offset 140000.
# Fetching rows 140501 to 141000...
# Fetching rows 141001 to 141500...
# Fetching rows 141501 to 142000...
# Fetching rows 142001 to 142500...
# Fetching rows 142501 to 143000...
# Fetching rows 143001 to 143500...
# Fetching rows 143501 to 144000...
# Fetching rows 144001 to 144500...
# Fetching rows 144501 to 145000...
# Fetching rows 145001 to 145500...
# Fetching rows 145501 to 146000...
# Fetching rows 146001 to 146500...
# Fetching rows 146501 to 147000...
# Fetching rows 147001 to 147500...
# Fetching rows 147501 to 148000...
# Fetching rows 148001 to 148500...
# Fetching rows 148501 to 149000...
# Fetching rows 149001 to 149500...
# Fetching rows 149501 to 150000...
# Fetching rows 150001 to 150500...
# Saved intermediate dataset up to offset 150000.
# Fetching rows 150501 to 151000...
# Fetching rows 151001 to 151500...
# Fetching rows 151501 to 152000...
# Fetching rows 152001 to 152500...
# Fetching rows 152501 to 153000...
# Fetching rows 153001 to 153500...
# Fetching rows 153501 to 154000...
# Fetching rows 154001 to 154500...
# Fetching rows 154501 to 155000...
# Fetching rows 155001 to 155500...
# Fetching rows 155501 to 156000...
# Fetching rows 156001 to 156500...
# Fetching rows 156501 to 157000...
# Fetching rows 157001 to 157500...
# Fetching rows 157501 to 158000...
# Fetching rows 158001 to 158500...
# Fetching rows 158501 to 159000...
# Fetching rows 159001 to 159500...
# Fetching rows 159501 to 160000...
# Fetching rows 160001 to 160500...
# Saved intermediate dataset up to offset 160000.
# Fetching rows 160501 to 161000...
# Fetching rows 161001 to 161500...
# Fetching rows 161501 to 162000...
# Fetching rows 162001 to 162500...
# Fetching rows 162501 to 163000...
# Fetching rows 163001 to 163500...
# Fetching rows 163501 to 164000...
# Fetching rows 164001 to 164500...
# Fetching rows 164501 to 165000...
# Fetching rows 165001 to 165500...
# Fetching rows 165501 to 166000...
# Fetching rows 166001 to 166500...
# Fetching rows 166501 to 167000...
# Fetching rows 167001 to 167500...
# Fetching rows 167501 to 168000...
# Fetching rows 168001 to 168500...
# Fetching rows 168501 to 169000...
# Fetching rows 169001 to 169500...
# Fetching rows 169501 to 170000...
# Fetching rows 170001 to 170500...
# Saved intermediate dataset up to offset 170000.
# Fetching rows 170501 to 171000...
# Fetching rows 171001 to 171500...
# Fetching rows 171501 to 172000...
# Fetching rows 172001 to 172500...
# Fetching rows 172501 to 173000...
# Fetching rows 173001 to 173500...
# Fetching rows 173501 to 174000...
# Fetching rows 174001 to 174500...
# Fetching rows 174501 to 175000...
# Fetching rows 175001 to 175500...
# Fetching rows 175501 to 176000...
# Fetching rows 176001 to 176500...
# Fetching rows 176501 to 177000...
# Fetching rows 177001 to 177500...
# Fetching rows 177501 to 178000...
# Fetching rows 178001 to 178500...
# Fetching rows 178501 to 179000...
# Fetching rows 179001 to 179500...
# Fetching rows 179501 to 180000...
# Fetching rows 180001 to 180500...
# Saved intermediate dataset up to offset 180000.
# Fetching rows 180501 to 181000...
# Fetching rows 181001 to 181500...
# Fetching rows 181501 to 182000...
# Fetching rows 182001 to 182500...
# Fetching rows 182501 to 183000...
# Fetching rows 183001 to 183500...
# Fetching rows 183501 to 184000...
# Fetching rows 184001 to 184500...
# Fetching rows 184501 to 185000...
# Fetching rows 185001 to 185500...
# Fetching rows 185501 to 186000...
# Fetching rows 186001 to 186500...
# Fetching rows 186501 to 187000...
# Fetching rows 187001 to 187500...
# Fetching rows 187501 to 188000...
# Fetching rows 188001 to 188500...
# Fetching rows 188501 to 189000...
# Fetching rows 189001 to 189500...
# Fetching rows 189501 to 190000...
# Fetching rows 190001 to 190500...
# Saved intermediate dataset up to offset 190000.
# Fetching rows 190501 to 191000...
# Fetching rows 191001 to 191500...
# Fetching rows 191501 to 192000...
# Fetching rows 192001 to 192500...
# Fetching rows 192501 to 193000...
# Fetching rows 193001 to 193500...
# Fetching rows 193501 to 194000...
# Fetching rows 194001 to 194500...
# Fetching rows 194501 to 195000...
# Fetching rows 195001 to 195500...
# Fetching rows 195501 to 196000...
# Fetching rows 196001 to 196500...
# Fetching rows 196501 to 197000...
# Fetching rows 197001 to 197500...
# Fetching rows 197501 to 198000...
# Fetching rows 198001 to 198500...
# Fetching rows 198501 to 199000...
# Fetching rows 199001 to 199500...
# Fetching rows 199501 to 200000...
# Fetching rows 200001 to 200500...
# Saved intermediate dataset up to offset 200000.
# Fetching rows 200501 to 201000...
# Fetching rows 201001 to 201500...
# Fetching rows 201501 to 202000...
# Fetching rows 202001 to 202500...
# Fetching rows 202501 to 203000...
# Fetching rows 203001 to 203500...
# Fetching rows 203501 to 204000...
# Fetching rows 204001 to 204500...
# Fetching rows 204501 to 205000...
# Fetching rows 205001 to 205500...
# Fetching rows 205501 to 206000...
# Fetching rows 206001 to 206500...
# Fetching rows 206501 to 207000...
# Fetching rows 207001 to 207500...
# Fetching rows 207501 to 208000...
# Fetching rows 208001 to 208500...
# Fetching rows 208501 to 209000...
# Fetching rows 209001 to 209500...
# Fetching rows 209501 to 210000...
# Fetching rows 210001 to 210500...
# Saved intermediate dataset up to offset 210000.
# Fetching rows 210501 to 211000...
# Fetching rows 211001 to 211500...
# Fetching rows 211501 to 212000...
# Fetching rows 212001 to 212500...
# Fetching rows 212501 to 213000...
# Fetching rows 213001 to 213500...
# Fetching rows 213501 to 214000...
# Fetching rows 214001 to 214500...
# Fetching rows 214501 to 215000...
# Fetching rows 215001 to 215500...
# Fetching rows 215501 to 216000...
# Fetching rows 216001 to 216500...
# Fetching rows 216501 to 217000...
# Fetching rows 217001 to 217500...
# Fetching rows 217501 to 218000...
# Fetching rows 218001 to 218500...
# Fetching rows 218501 to 219000...
# Fetching rows 219001 to 219500...
# Fetching rows 219501 to 220000...
# Fetching rows 220001 to 220500...
# Saved intermediate dataset up to offset 220000.
# Fetching rows 220501 to 221000...
# Fetching rows 221001 to 221500...
# Fetching rows 221501 to 222000...
# Fetching rows 222001 to 222500...
# Fetching rows 222501 to 223000...
# Fetching rows 223001 to 223500...
# Fetching rows 223501 to 224000...
# Fetching rows 224001 to 224500...
# Fetching rows 224501 to 225000...
# Fetching rows 225001 to 225500...
# Fetching rows 225501 to 226000...
# Fetching rows 226001 to 226500...
# Fetching rows 226501 to 227000...
# Fetching rows 227001 to 227500...
# Fetching rows 227501 to 228000...
# Fetching rows 228001 to 228500...
# Fetching rows 228501 to 229000...
# Fetching rows 229001 to 229500...
# Fetching rows 229501 to 230000...
# Fetching rows 230001 to 230500...
# Saved intermediate dataset up to offset 230000.
# Fetching rows 230501 to 231000...
# Fetching rows 231001 to 231500...
# Fetching rows 231501 to 232000...
# Fetching rows 232001 to 232500...
# Fetching rows 232501 to 233000...
# Fetching rows 233001 to 233500...
# Fetching rows 233501 to 234000...
# Fetching rows 234001 to 234500...
# Fetching rows 234501 to 235000...
# Fetching rows 235001 to 235500...
# Fetching rows 235501 to 236000...
# Fetching rows 236001 to 236500...
# Fetching rows 236501 to 237000...
# Fetching rows 237001 to 237500...
# Fetching rows 237501 to 238000...
# Fetching rows 238001 to 238500...
# Fetching rows 238501 to 239000...
# Fetching rows 239001 to 239500...
# Fetching rows 239501 to 240000...
# Fetching rows 240001 to 240500...
# Saved intermediate dataset up to offset 240000.
# Fetching rows 240501 to 241000...
# Fetching rows 241001 to 241500...
# Fetching rows 241501 to 242000...
# Fetching rows 242001 to 242500...
# Fetching rows 242501 to 243000...
# Fetching rows 243001 to 243500...
# Fetching rows 243501 to 244000...
# Fetching rows 244001 to 244500...
# Fetching rows 244501 to 245000...
# Fetching rows 245001 to 245500...
# Fetching rows 245501 to 246000...
# Fetching rows 246001 to 246500...
# Fetching rows 246501 to 247000...
# Fetching rows 247001 to 247500...
# Fetching rows 247501 to 248000...
# Fetching rows 248001 to 248500...
# Fetching rows 248501 to 249000...
# Fetching rows 249001 to 249500...
# Fetching rows 249501 to 250000...
# Fetching rows 250001 to 250500...
# Saved intermediate dataset up to offset 250000.
# Fetching rows 250501 to 251000...
# Fetching rows 251001 to 251500...
# Fetching rows 251501 to 252000...
# Fetching rows 252001 to 252500...
# Fetching rows 252501 to 253000...
# Fetching rows 253001 to 253500...
# Fetching rows 253501 to 254000...
# Fetching rows 254001 to 254500...
# Fetching rows 254501 to 255000...
# Fetching rows 255001 to 255500...
# Fetching rows 255501 to 256000...
# Fetching rows 256001 to 256500...
# Fetching rows 256501 to 257000...
# Fetching rows 257001 to 257500...
# Fetching rows 257501 to 258000...
# Fetching rows 258001 to 258500...
# Fetching rows 258501 to 259000...
# Fetching rows 259001 to 259500...
# Fetching rows 259501 to 260000...
# Fetching rows 260001 to 260500...
# Saved intermediate dataset up to offset 260000.
# Fetching rows 260501 to 261000...
# Fetching rows 261001 to 261500...
# Fetching rows 261501 to 262000...
# Fetching rows 262001 to 262500...
# Fetching rows 262501 to 263000...
# Fetching rows 263001 to 263500...
# Fetching rows 263501 to 264000...
# Fetching rows 264001 to 264500...
# Fetching rows 264501 to 265000...
# Fetching rows 265001 to 265500...
# Fetching rows 265501 to 266000...
# Fetching rows 266001 to 266500...
# Fetching rows 266501 to 267000...
# Fetching rows 267001 to 267500...
# Fetching rows 267501 to 268000...
# Fetching rows 268001 to 268500...
# Fetching rows 268501 to 269000...
# Fetching rows 269001 to 269500...
# Fetching rows 269501 to 270000...
# Fetching rows 270001 to 270500...
# Saved intermediate dataset up to offset 270000.
# Fetching rows 270501 to 271000...
# Fetching rows 271001 to 271500...
# Fetching rows 271501 to 272000...
# Fetching rows 272001 to 272500...
# Fetching rows 272501 to 273000...
# Fetching rows 273001 to 273500...
# Fetching rows 273501 to 274000...
# Fetching rows 274001 to 274500...
# Fetching rows 274501 to 275000...
# Fetching rows 275001 to 275500...
# Fetching rows 275501 to 276000...
# Fetching rows 276001 to 276500...
# Fetching rows 276501 to 277000...
# Fetching rows 277001 to 277500...
# Fetching rows 277501 to 278000...
# Fetching rows 278001 to 278500...
# Fetching rows 278501 to 279000...
# Fetching rows 279001 to 279500...
# Fetching rows 279501 to 280000...
# Fetching rows 280001 to 280500...
# Saved intermediate dataset up to offset 280000.
# Fetching rows 280501 to 281000...
# Fetching rows 281001 to 281500...
# Fetching rows 281501 to 282000...
# Fetching rows 282001 to 282500...
# Fetching rows 282501 to 283000...
# Fetching rows 283001 to 283500...
# Fetching rows 283501 to 284000...
# Fetching rows 284001 to 284500...
# Fetching rows 284501 to 285000...
# Fetching rows 285001 to 285500...
# Fetching rows 285501 to 286000...
# Fetching rows 286001 to 286500...
# Fetching rows 286501 to 287000...
# Fetching rows 287001 to 287500...
# Fetching rows 287501 to 288000...
# Fetching rows 288001 to 288500...
# Fetching rows 288501 to 289000...
# Fetching rows 289001 to 289500...
# Fetching rows 289501 to 290000...
# Fetching rows 290001 to 290500...
# Saved intermediate dataset up to offset 290000.
# Fetching rows 290501 to 291000...
# Fetching rows 291001 to 291500...
# Fetching rows 291501 to 292000...
# Fetching rows 292001 to 292500...
# Fetching rows 292501 to 293000...
# Fetching rows 293001 to 293500...
# Fetching rows 293501 to 294000...
# Fetching rows 294001 to 294500...
# Fetching rows 294501 to 295000...
# Fetching rows 295001 to 295500...
# Fetching rows 295501 to 296000...
# Fetching rows 296001 to 296500...
# Fetching rows 296501 to 297000...
# Fetching rows 297001 to 297500...
# Fetching rows 297501 to 298000...
# Fetching rows 298001 to 298500...
# Fetching rows 298501 to 299000...
# Fetching rows 299001 to 299500...
# Fetching rows 299501 to 300000...
# Fetching rows 300001 to 300500...
# Saved intermediate dataset up to offset 300000.
# Fetching rows 300501 to 301000...
# Fetching rows 301001 to 301500...
# Fetching rows 301501 to 302000...
# Fetching rows 302001 to 302500...
# Fetching rows 302501 to 303000...
# Fetching rows 303001 to 303500...
# Fetching rows 303501 to 304000...
# Fetching rows 304001 to 304500...
# Fetching rows 304501 to 305000...
# Fetching rows 305001 to 305500...
# Fetching rows 305501 to 306000...
# Fetching rows 306001 to 306500...
# Fetching rows 306501 to 307000...
# Fetching rows 307001 to 307500...
# Fetching rows 307501 to 308000...
# Fetching rows 308001 to 308500...
# Fetching rows 308501 to 309000...
# Fetching rows 309001 to 309500...
# Fetching rows 309501 to 310000...
# Fetching rows 310001 to 310500...
# Saved intermediate dataset up to offset 310000.
# Fetching rows 310501 to 311000...
# Fetching rows 311001 to 311500...
# Fetching rows 311501 to 312000...
# Fetching rows 312001 to 312500...
# Fetching rows 312501 to 313000...
# Fetching rows 313001 to 313500...
# Fetching rows 313501 to 314000...
# Fetching rows 314001 to 314500...
# Fetching rows 314501 to 315000...
# Fetching rows 315001 to 315500...
# Fetching rows 315501 to 316000...
# Fetching rows 316001 to 316500...
# Fetching rows 316501 to 317000...
# Fetching rows 317001 to 317500...
# Fetching rows 317501 to 318000...
# Fetching rows 318001 to 318500...
# Fetching rows 318501 to 319000...
# Fetching rows 319001 to 319500...
# Fetching rows 319501 to 320000...
# Fetching rows 320001 to 320500...
# Saved intermediate dataset up to offset 320000.
# Fetching rows 320501 to 321000...
# Fetching rows 321001 to 321500...
# Fetching rows 321501 to 322000...
# Fetching rows 322001 to 322500...
# Fetching rows 322501 to 323000...
# Fetching rows 323001 to 323500...
# Fetching rows 323501 to 324000...
# Fetching rows 324001 to 324500...
# Fetching rows 324501 to 325000...
# Fetching rows 325001 to 325500...
# Fetching rows 325501 to 326000...
# Fetching rows 326001 to 326500...
# Fetching rows 326501 to 327000...
# Fetching rows 327001 to 327500...
# Fetching rows 327501 to 328000...
# Fetching rows 328001 to 328500...
# Fetching rows 328501 to 329000...
# Fetching rows 329001 to 329500...
# Fetching rows 329501 to 330000...
# Fetching rows 330001 to 330500...
# Saved intermediate dataset up to offset 330000.
# Fetching rows 330501 to 331000...
# Fetching rows 331001 to 331500...
# Fetching rows 331501 to 332000...
# Fetching rows 332001 to 332500...
# Fetching rows 332501 to 333000...
# Fetching rows 333001 to 333500...
# Fetching rows 333501 to 334000...
# Fetching rows 334001 to 334500...
# Fetching rows 334501 to 335000...
# Fetching rows 335001 to 335500...
# Fetching rows 335501 to 336000...
# Fetching rows 336001 to 336500...
# Fetching rows 336501 to 337000...
# Fetching rows 337001 to 337500...
# Fetching rows 337501 to 338000...
# Fetching rows 338001 to 338500...
# Fetching rows 338501 to 339000...
# Fetching rows 339001 to 339500...
# Fetching rows 339501 to 340000...
# Fetching rows 340001 to 340500...
# Saved intermediate dataset up to offset 340000.
# Fetching rows 340501 to 341000...
# Fetching rows 341001 to 341500...
# Fetching rows 341501 to 342000...
# Fetching rows 342001 to 342500...
# Fetching rows 342501 to 343000...
# Fetching rows 343001 to 343500...
# Fetching rows 343501 to 344000...
# Fetching rows 344001 to 344500...
# Fetching rows 344501 to 345000...
# Fetching rows 345001 to 345500...
# Fetching rows 345501 to 346000...
# Fetching rows 346001 to 346500...
# Fetching rows 346501 to 347000...
# Fetching rows 347001 to 347500...
# Fetching rows 347501 to 348000...
# Fetching rows 348001 to 348500...
# Fetching rows 348501 to 349000...
# Fetching rows 349001 to 349500...
# Fetching rows 349501 to 350000...
# Fetching rows 350001 to 350500...
# Saved intermediate dataset up to offset 350000.
# Fetching rows 350501 to 351000...
# Fetching rows 351001 to 351500...
# Fetching rows 351501 to 352000...
# Fetching rows 352001 to 352500...
# Fetching rows 352501 to 353000...
# Fetching rows 353001 to 353500...
# Fetching rows 353501 to 354000...
# Fetching rows 354001 to 354500...
# Fetching rows 354501 to 355000...
# Fetching rows 355001 to 355500...
# Fetching rows 355501 to 356000...
# Fetching rows 356001 to 356500...
# Fetching rows 356501 to 357000...
# Fetching rows 357001 to 357500...
# Fetching rows 357501 to 358000...
# Fetching rows 358001 to 358500...
# Fetching rows 358501 to 359000...
# Fetching rows 359001 to 359500...
# Fetching rows 359501 to 360000...
# Fetching rows 360001 to 360500...
# Saved intermediate dataset up to offset 360000.
# Fetching rows 360501 to 361000...
# Fetching rows 361001 to 361500...
# Fetching rows 361501 to 362000...
# Fetching rows 362001 to 362500...
# Fetching rows 362501 to 363000...
# Fetching rows 363001 to 363500...
# Fetching rows 363501 to 364000...
# Fetching rows 364001 to 364500...
# Fetching rows 364501 to 365000...
# Fetching rows 365001 to 365500...
# Fetching rows 365501 to 366000...
# Fetching rows 366001 to 366500...
# Fetching rows 366501 to 367000...
# Fetching rows 367001 to 367500...
# Fetching rows 367501 to 368000...
# Fetching rows 368001 to 368500...
# Fetching rows 368501 to 369000...
# Fetching rows 369001 to 369500...
# Fetching rows 369501 to 370000...
# Fetching rows 370001 to 370500...
# Saved intermediate dataset up to offset 370000.
# Fetching rows 370501 to 371000...
# Fetching rows 371001 to 371500...
# Fetching rows 371501 to 372000...
# Fetching rows 372001 to 372500...
# Fetching rows 372501 to 373000...
# Fetching rows 373001 to 373500...
# Fetching rows 373501 to 374000...
# Fetching rows 374001 to 374500...
# Fetching rows 374501 to 375000...
# Fetching rows 375001 to 375500...
# Fetching rows 375501 to 376000...
# Fetching rows 376001 to 376500...
# Fetching rows 376501 to 377000...
# Fetching rows 377001 to 377500...
# Fetching rows 377501 to 378000...
# Fetching rows 378001 to 378500...
# Fetching rows 378501 to 379000...
# Fetching rows 379001 to 379500...
# Fetching rows 379501 to 380000...
# Fetching rows 380001 to 380500...
# Saved intermediate dataset up to offset 380000.
# Fetching rows 380501 to 381000...
# Fetching rows 381001 to 381500...
# Fetching rows 381501 to 382000...
# Fetching rows 382001 to 382500...
# Fetching rows 382501 to 383000...
# Fetching rows 383001 to 383500...
# Fetching rows 383501 to 384000...
# Fetching rows 384001 to 384500...
# Fetching rows 384501 to 385000...
# Fetching rows 385001 to 385500...
# Fetching rows 385501 to 386000...
# Fetching rows 386001 to 386500...
# Fetching rows 386501 to 387000...
# Fetching rows 387001 to 387500...
# Fetching rows 387501 to 388000...
# Fetching rows 388001 to 388500...
# Fetching rows 388501 to 389000...
# Fetching rows 389001 to 389500...
# Fetching rows 389501 to 390000...
# Fetching rows 390001 to 390500...
# Saved intermediate dataset up to offset 390000.
# Fetching rows 390501 to 391000...
# Fetching rows 391001 to 391500...
# Fetching rows 391501 to 392000...
# Fetching rows 392001 to 392500...
# Fetching rows 392501 to 393000...
# Fetching rows 393001 to 393500...
# Fetching rows 393501 to 394000...
# Fetching rows 394001 to 394500...
# Fetching rows 394501 to 395000...
# Fetching rows 395001 to 395500...
# Fetching rows 395501 to 396000...
# Fetching rows 396001 to 396500...
# Fetching rows 396501 to 397000...
# Fetching rows 397001 to 397500...
# Fetching rows 397501 to 398000...
# Fetching rows 398001 to 398500...
# Fetching rows 398501 to 399000...
# Fetching rows 399001 to 399500...
# Fetching rows 399501 to 400000...
# Fetching rows 400001 to 400500...
# Saved intermediate dataset up to offset 400000.
# Fetching rows 400501 to 401000...
# Fetching rows 401001 to 401500...
# Fetching rows 401501 to 402000...
# Fetching rows 402001 to 402500...
# Fetching rows 402501 to 403000...
# Fetching rows 403001 to 403500...
# Fetching rows 403501 to 404000...
# Fetching rows 404001 to 404500...
# Fetching rows 404501 to 405000...
# Fetching rows 405001 to 405500...
# Fetching rows 405501 to 406000...
# Fetching rows 406001 to 406500...
# Fetching rows 406501 to 407000...
# Fetching rows 407001 to 407500...
# Fetching rows 407501 to 408000...
# Fetching rows 408001 to 408500...
# Fetching rows 408501 to 409000...
# Fetching rows 409001 to 409500...
# Fetching rows 409501 to 410000...
# Fetching rows 410001 to 410500...
# Saved intermediate dataset up to offset 410000.
# Fetching rows 410501 to 411000...
# Fetching rows 411001 to 411500...
# Fetching rows 411501 to 412000...
# Fetching rows 412001 to 412500...
# Fetching rows 412501 to 413000...
# Fetching rows 413001 to 413500...
# Fetching rows 413501 to 414000...
# Fetching rows 414001 to 414500...
# Fetching rows 414501 to 415000...
# Fetching rows 415001 to 415500...
# Fetching rows 415501 to 416000...
# Fetching rows 416001 to 416500...
# Fetching rows 416501 to 417000...
# Fetching rows 417001 to 417500...
# Fetching rows 417501 to 418000...
# Fetching rows 418001 to 418500...
# Fetching rows 418501 to 419000...
# Fetching rows 419001 to 419500...
# Fetching rows 419501 to 420000...
# Fetching rows 420001 to 420500...
# Saved intermediate dataset up to offset 420000.
# Fetching rows 420501 to 421000...
# Fetching rows 421001 to 421500...
# Fetching rows 421501 to 422000...
# Fetching rows 422001 to 422500...
# Fetching rows 422501 to 423000...
# Fetching rows 423001 to 423500...
# Fetching rows 423501 to 424000...
# Fetching rows 424001 to 424500...
# Fetching rows 424501 to 425000...
# Fetching rows 425001 to 425500...
# Fetching rows 425501 to 426000...
# Fetching rows 426001 to 426500...
# Fetching rows 426501 to 427000...
# Fetching rows 427001 to 427500...
# Fetching rows 427501 to 428000...
# Fetching rows 428001 to 428500...
# Fetching rows 428501 to 429000...
# Fetching rows 429001 to 429500...
# Fetching rows 429501 to 430000...
# Fetching rows 430001 to 430500...
# Saved intermediate dataset up to offset 430000.
# Fetching rows 430501 to 431000...
# Fetching rows 431001 to 431500...
# Fetching rows 431501 to 432000...
# Fetching rows 432001 to 432500...
# Fetching rows 432501 to 433000...
# Fetching rows 433001 to 433500...
# Fetching rows 433501 to 434000...
# Fetching rows 434001 to 434500...
# Fetching rows 434501 to 435000...
# Fetching rows 435001 to 435500...
# Fetching rows 435501 to 436000...
# Fetching rows 436001 to 436500...
# Fetching rows 436501 to 437000...
# Fetching rows 437001 to 437500...
# Fetching rows 437501 to 438000...
# Fetching rows 438001 to 438500...
# Fetching rows 438501 to 439000...
# Fetching rows 439001 to 439500...
# Fetching rows 439501 to 440000...
# Fetching rows 440001 to 440500...
# Saved intermediate dataset up to offset 440000.
# Fetching rows 440501 to 441000...
# Fetching rows 441001 to 441500...
# Fetching rows 441501 to 442000...
# Fetching rows 442001 to 442500...
# Fetching rows 442501 to 443000...
# Fetching rows 443001 to 443500...
# Fetching rows 443501 to 444000...
# Fetching rows 444001 to 444500...
# Fetching rows 444501 to 445000...
# Fetching rows 445001 to 445500...
# Fetching rows 445501 to 446000...
# Fetching rows 446001 to 446500...
# Fetching rows 446501 to 447000...
# Fetching rows 447001 to 447500...
# Fetching rows 447501 to 448000...
# Fetching rows 448001 to 448500...
# Fetching rows 448501 to 449000...
# Fetching rows 449001 to 449500...
# Fetching rows 449501 to 450000...
# Fetching rows 450001 to 450500...
# Saved intermediate dataset up to offset 450000.
# Fetching rows 450501 to 451000...
# Fetching rows 451001 to 451500...
# Fetching rows 451501 to 452000...
# Fetching rows 452001 to 452500...
# Fetching rows 452501 to 453000...
# Fetching rows 453001 to 453500...
# Fetching rows 453501 to 454000...
# Fetching rows 454001 to 454500...
# Fetching rows 454501 to 455000...
# Fetching rows 455001 to 455500...
# Fetching rows 455501 to 456000...
# Fetching rows 456001 to 456500...
# Fetching rows 456501 to 457000...
# Fetching rows 457001 to 457500...
# Fetching rows 457501 to 458000...
# Fetching rows 458001 to 458500...
# Fetching rows 458501 to 459000...
# Fetching rows 459001 to 459500...
# Fetching rows 459501 to 460000...
# Fetching rows 460001 to 460500...
# Saved intermediate dataset up to offset 460000.
# Fetching rows 460501 to 461000...
# Fetching rows 461001 to 461500...
# Fetching rows 461501 to 462000...
# Fetching rows 462001 to 462500...
# Fetching rows 462501 to 463000...
# Fetching rows 463001 to 463500...
# Fetching rows 463501 to 464000...
# Fetching rows 464001 to 464500...
# Fetching rows 464501 to 465000...
# Fetching rows 465001 to 465500...
# Fetching rows 465501 to 466000...
# Fetching rows 466001 to 466500...
# Fetching rows 466501 to 467000...
# Fetching rows 467001 to 467500...
# Fetching rows 467501 to 468000...
# Fetching rows 468001 to 468500...
# Fetching rows 468501 to 469000...
# Fetching rows 469001 to 469500...
# Fetching rows 469501 to 470000...
# Fetching rows 470001 to 470500...
# Saved intermediate dataset up to offset 470000.
# Fetching rows 470501 to 471000...
# Fetching rows 471001 to 471500...
# Fetching rows 471501 to 472000...
# Fetching rows 472001 to 472500...
# Fetching rows 472501 to 473000...
# Fetching rows 473001 to 473500...
# Fetching rows 473501 to 474000...
# Fetching rows 474001 to 474500...
# Fetching rows 474501 to 475000...
# Fetching rows 475001 to 475500...
# Fetching rows 475501 to 476000...
# Fetching rows 476001 to 476500...
# Fetching rows 476501 to 477000...
# Fetching rows 477001 to 477500...
# Fetching rows 477501 to 478000...
# Fetching rows 478001 to 478500...
# Fetching rows 478501 to 479000...
# Fetching rows 479001 to 479500...
# Fetching rows 479501 to 480000...
# Fetching rows 480001 to 480500...
# Saved intermediate dataset up to offset 480000.
# Fetching rows 480501 to 481000...
# Fetching rows 481001 to 481500...
# Fetching rows 481501 to 482000...
# Fetching rows 482001 to 482500...
# Fetching rows 482501 to 483000...
# Fetching rows 483001 to 483500...
# Fetching rows 483501 to 484000...
# Fetching rows 484001 to 484500...
# Fetching rows 484501 to 485000...
# Fetching rows 485001 to 485500...
# Fetching rows 485501 to 486000...
# Fetching rows 486001 to 486500...
# Fetching rows 486501 to 487000...
# Fetching rows 487001 to 487500...
# Fetching rows 487501 to 488000...
# Fetching rows 488001 to 488500...
# Fetching rows 488501 to 489000...
# Fetching rows 489001 to 489500...
# Fetching rows 489501 to 490000...
# Fetching rows 490001 to 490500...
# Saved intermediate dataset up to offset 490000.
# Fetching rows 490501 to 491000...
# Fetching rows 491001 to 491500...
# Fetching rows 491501 to 492000...
# Fetching rows 492001 to 492500...
# Fetching rows 492501 to 493000...
# Fetching rows 493001 to 493500...
# Fetching rows 493501 to 494000...
# Fetching rows 494001 to 494500...
# Fetching rows 494501 to 495000...
# Fetching rows 495001 to 495500...
# Fetching rows 495501 to 496000...
# Fetching rows 496001 to 496500...
# Fetching rows 496501 to 497000...
# Fetching rows 497001 to 497500...
# Fetching rows 497501 to 498000...
# Fetching rows 498001 to 498500...
# Fetching rows 498501 to 499000...
# Fetching rows 499001 to 499500...
# Fetching rows 499501 to 500000...
# Fetching rows 500001 to 500500...
# Saved intermediate dataset up to offset 500000.
# Fetching rows 500501 to 501000...
# Fetching rows 501001 to 501500...
# Fetching rows 501501 to 502000...
# Fetching rows 502001 to 502500...
# Fetching rows 502501 to 503000...
# Fetching rows 503001 to 503500...
# Fetching rows 503501 to 504000...
# Fetching rows 504001 to 504500...
# Fetching rows 504501 to 505000...
# Fetching rows 505001 to 505500...
# Fetching rows 505501 to 506000...
# Fetching rows 506001 to 506500...
# Fetching rows 506501 to 507000...
# Fetching rows 507001 to 507500...
# Fetching rows 507501 to 508000...
# Fetching rows 508001 to 508500...
# Fetching rows 508501 to 509000...
# Fetching rows 509001 to 509500...
# Fetching rows 509501 to 510000...
# Fetching rows 510001 to 510500...
# Saved intermediate dataset up to offset 510000.
# Fetching rows 510501 to 511000...
# Fetching rows 511001 to 511500...
# Fetching rows 511501 to 512000...
# Fetching rows 512001 to 512500...
# Fetching rows 512501 to 513000...
# Fetching rows 513001 to 513500...
# Fetching rows 513501 to 514000...
# Fetching rows 514001 to 514500...
# Fetching rows 514501 to 515000...
# Fetching rows 515001 to 515500...
# Fetching rows 515501 to 516000...
# Fetching rows 516001 to 516500...
# Fetching rows 516501 to 517000...
# Fetching rows 517001 to 517500...
# Fetching rows 517501 to 518000...
# Fetching rows 518001 to 518500...
# Fetching rows 518501 to 519000...
# Fetching rows 519001 to 519500...
# Fetching rows 519501 to 520000...
# Fetching rows 520001 to 520500...
# Saved intermediate dataset up to offset 520000.
# Fetching rows 520501 to 521000...
# Fetching rows 521001 to 521500...
# Fetching rows 521501 to 522000...
# Fetching rows 522001 to 522500...
# Fetching rows 522501 to 523000...
# Fetching rows 523001 to 523500...
# Fetching rows 523501 to 524000...
# Fetching rows 524001 to 524500...
# Fetching rows 524501 to 525000...
# Fetching rows 525001 to 525500...
# Fetching rows 525501 to 526000...
# Fetching rows 526001 to 526500...
# Fetching rows 526501 to 527000...
# Fetching rows 527001 to 527500...
# Fetching rows 527501 to 528000...
# Fetching rows 528001 to 528500...
# Fetching rows 528501 to 529000...
# Fetching rows 529001 to 529500...
# Fetching rows 529501 to 530000...
# Fetching rows 530001 to 530500...
# Saved intermediate dataset up to offset 530000.
# Fetching rows 530501 to 531000...
# Fetching rows 531001 to 531500...
# Fetching rows 531501 to 532000...
# Fetching rows 532001 to 532500...
# Fetching rows 532501 to 533000...
# Fetching rows 533001 to 533500...
# Fetching rows 533501 to 534000...
# Fetching rows 534001 to 534500...
# Fetching rows 534501 to 535000...
# Fetching rows 535001 to 535500...
# Fetching rows 535501 to 536000...
# Fetching rows 536001 to 536500...
# Fetching rows 536501 to 537000...
# Fetching rows 537001 to 537500...
# Fetching rows 537501 to 538000...
# Fetching rows 538001 to 538500...
# Fetching rows 538501 to 539000...
# Fetching rows 539001 to 539500...
# Fetching rows 539501 to 540000...
# Fetching rows 540001 to 540500...
# Saved intermediate dataset up to offset 540000.
# Fetching rows 540501 to 541000...
# Fetching rows 541001 to 541500...
# Fetching rows 541501 to 542000...
# Fetching rows 542001 to 542500...
# Fetching rows 542501 to 543000...
# Fetching rows 543001 to 543500...
# Fetching rows 543501 to 544000...
# Fetching rows 544001 to 544500...
# Fetching rows 544501 to 545000...
# Fetching rows 545001 to 545500...
# Fetching rows 545501 to 546000...
# Fetching rows 546001 to 546500...
# Fetching rows 546501 to 547000...
# Fetching rows 547001 to 547500...
# Fetching rows 547501 to 548000...
# Fetching rows 548001 to 548500...
# Fetching rows 548501 to 549000...
# Fetching rows 549001 to 549500...
# Fetching rows 549501 to 550000...
# Fetching rows 550001 to 550500...
# Saved intermediate dataset up to offset 550000.
# Fetching rows 550501 to 551000...
# Fetching rows 551001 to 551500...
# Fetching rows 551501 to 552000...
# Fetching rows 552001 to 552500...
# Fetching rows 552501 to 553000...
# Fetching rows 553001 to 553500...
# Fetching rows 553501 to 554000...
# Fetching rows 554001 to 554500...
# Fetching rows 554501 to 555000...
# Fetching rows 555001 to 555500...
# Fetching rows 555501 to 556000...
# Fetching rows 556001 to 556500...
# Fetching rows 556501 to 557000...
# Fetching rows 557001 to 557500...
# Fetching rows 557501 to 558000...
# Fetching rows 558001 to 558500...
# Fetching rows 558501 to 559000...
# Fetching rows 559001 to 559500...
# Fetching rows 559501 to 560000...
# Fetching rows 560001 to 560500...
# Saved intermediate dataset up to offset 560000.
# Fetching rows 560501 to 561000...
# Fetching rows 561001 to 561500...
# Fetching rows 561501 to 562000...
# Fetching rows 562001 to 562500...
# Fetching rows 562501 to 563000...
# Fetching rows 563001 to 563500...
# Fetching rows 563501 to 564000...
# Fetching rows 564001 to 564500...
# Fetching rows 564501 to 565000...
# Fetching rows 565001 to 565500...
# Fetching rows 565501 to 566000...
# Fetching rows 566001 to 566500...
# Fetching rows 566501 to 567000...
# Fetching rows 567001 to 567500...
# Fetching rows 567501 to 568000...
# Fetching rows 568001 to 568500...
# Fetching rows 568501 to 569000...
# Fetching rows 569001 to 569500...
# Fetching rows 569501 to 570000...
# Fetching rows 570001 to 570500...
# Saved intermediate dataset up to offset 570000.
# Fetching rows 570501 to 571000...
# Fetching rows 571001 to 571500...
# Fetching rows 571501 to 572000...
# Fetching rows 572001 to 572500...
# Fetching rows 572501 to 573000...
# Fetching rows 573001 to 573500...
# Fetching rows 573501 to 574000...
# Fetching rows 574001 to 574500...
# Fetching rows 574501 to 575000...
# Fetching rows 575001 to 575500...
# Fetching rows 575501 to 576000...
# Fetching rows 576001 to 576500...
# Fetching rows 576501 to 577000...
# Fetching rows 577001 to 577500...
# Fetching rows 577501 to 578000...
# Fetching rows 578001 to 578500...
# Fetching rows 578501 to 579000...
# Fetching rows 579001 to 579500...
# Fetching rows 579501 to 580000...
# Fetching rows 580001 to 580500...
# Saved intermediate dataset up to offset 580000.
# Fetching rows 580501 to 581000...
# Fetching rows 581001 to 581500...
# Fetching rows 581501 to 582000...
# Fetching rows 582001 to 582500...
# Fetching rows 582501 to 583000...
# Fetching rows 583001 to 583500...
# Fetching rows 583501 to 584000...
# Fetching rows 584001 to 584500...
# Fetching rows 584501 to 585000...
# Fetching rows 585001 to 585500...
# Fetching rows 585501 to 586000...
# Fetching rows 586001 to 586500...
# Fetching rows 586501 to 587000...
# Fetching rows 587001 to 587500...
# Fetching rows 587501 to 588000...
# Fetching rows 588001 to 588500...
# Fetching rows 588501 to 589000...
# Fetching rows 589001 to 589500...
# Fetching rows 589501 to 590000...
# Fetching rows 590001 to 590500...
# Saved intermediate dataset up to offset 590000.
# Fetching rows 590501 to 591000...
# Fetching rows 591001 to 591500...
# Fetching rows 591501 to 592000...
# Fetching rows 592001 to 592500...
# Fetching rows 592501 to 593000...
# Fetching rows 593001 to 593500...
# Fetching rows 593501 to 594000...
# Fetching rows 594001 to 594500...
# Fetching rows 594501 to 595000...
# Fetching rows 595001 to 595500...
# Fetching rows 595501 to 596000...
# Fetching rows 596001 to 596500...
# Fetching rows 596501 to 597000...
# Fetching rows 597001 to 597500...
# Fetching rows 597501 to 598000...
# Fetching rows 598001 to 598500...
# Fetching rows 598501 to 599000...
# Fetching rows 599001 to 599500...
# Fetching rows 599501 to 600000...
# Fetching rows 600001 to 600500...
# Saved intermediate dataset up to offset 600000.
# Fetching rows 600501 to 601000...
# Fetching rows 601001 to 601500...
# Fetching rows 601501 to 602000...
# Fetching rows 602001 to 602500...
# Fetching rows 602501 to 603000...
# Fetching rows 603001 to 603500...
# Fetching rows 603501 to 604000...
# Fetching rows 604001 to 604500...
# Fetching rows 604501 to 605000...
# Fetching rows 605001 to 605500...
# Fetching rows 605501 to 606000...
# Fetching rows 606001 to 606500...
# Fetching rows 606501 to 607000...
# Fetching rows 607001 to 607500...
# Fetching rows 607501 to 608000...
# Fetching rows 608001 to 608500...
# Fetching rows 608501 to 609000...
# Fetching rows 609001 to 609500...
# Fetching rows 609501 to 610000...
# Fetching rows 610001 to 610500...
# Saved intermediate dataset up to offset 610000.
# Fetching rows 610501 to 611000...
# Fetching rows 611001 to 611500...
# Fetching rows 611501 to 612000...
# Fetching rows 612001 to 612500...
# Fetching rows 612501 to 613000...
# Fetching rows 613001 to 613500...
# Fetching rows 613501 to 614000...
# Fetching rows 614001 to 614500...
# Fetching rows 614501 to 615000...
# Fetching rows 615001 to 615500...
# Fetching rows 615501 to 616000...
# Fetching rows 616001 to 616500...
# Fetching rows 616501 to 617000...
# Fetching rows 617001 to 617500...
# Fetching rows 617501 to 618000...
# Fetching rows 618001 to 618500...
# Fetching rows 618501 to 619000...
# Fetching rows 619001 to 619500...
# Fetching rows 619501 to 620000...
# Fetching rows 620001 to 620500...
# Saved intermediate dataset up to offset 620000.
# Fetching rows 620501 to 621000...
# Fetching rows 621001 to 621500...
# Fetching rows 621501 to 622000...
# Fetching rows 622001 to 622500...
# Fetching rows 622501 to 623000...
# Fetching rows 623001 to 623500...
# Fetching rows 623501 to 624000...
# Fetching rows 624001 to 624500...
# Fetching rows 624501 to 625000...
# Fetching rows 625001 to 625500...
# Fetching rows 625501 to 626000...
# Fetching rows 626001 to 626500...
# Fetching rows 626501 to 627000...
# Fetching rows 627001 to 627500...
# Fetching rows 627501 to 628000...
# Fetching rows 628001 to 628500...
# Fetching rows 628501 to 629000...
# Fetching rows 629001 to 629500...
# Fetching rows 629501 to 630000...
# Fetching rows 630001 to 630500...
# Saved intermediate dataset up to offset 630000.
# Fetching rows 630501 to 631000...
# Fetching rows 631001 to 631500...
# Fetching rows 631501 to 632000...
# Fetching rows 632001 to 632500...
# Fetching rows 632501 to 633000...
# Fetching rows 633001 to 633500...
# Fetching rows 633501 to 634000...
# Fetching rows 634001 to 634500...
# Fetching rows 634501 to 635000...
# Fetching rows 635001 to 635500...
# Fetching rows 635501 to 636000...
# Fetching rows 636001 to 636500...
# Fetching rows 636501 to 637000...
# Fetching rows 637001 to 637500...
# Fetching rows 637501 to 638000...
# Fetching rows 638001 to 638500...
# Fetching rows 638501 to 639000...
# Fetching rows 639001 to 639500...
# Fetching rows 639501 to 640000...
# Fetching rows 640001 to 640500...
# Saved intermediate dataset up to offset 640000.
# Fetching rows 640501 to 641000...
# Fetching rows 641001 to 641500...
# Fetching rows 641501 to 642000...
# Fetching rows 642001 to 642500...
# Fetching rows 642501 to 643000...
# Fetching rows 643001 to 643500...
# Fetching rows 643501 to 644000...
# Fetching rows 644001 to 644500...
# Fetching rows 644501 to 645000...
# Fetching rows 645001 to 645500...
# Fetching rows 645501 to 646000...
# Fetching rows 646001 to 646500...
# Fetching rows 646501 to 647000...
# Fetching rows 647001 to 647500...
# Fetching rows 647501 to 648000...
# Fetching rows 648001 to 648500...
# Fetching rows 648501 to 649000...
# Fetching rows 649001 to 649500...
# Fetching rows 649501 to 650000...
# Fetching rows 650001 to 650500...
# Saved intermediate dataset up to offset 650000.
# Fetching rows 650501 to 651000...
# Fetching rows 651001 to 651500...
# Fetching rows 651501 to 652000...
# Fetching rows 652001 to 652500...
# Fetching rows 652501 to 653000...
# Fetching rows 653001 to 653500...
# Fetching rows 653501 to 654000...
# Fetching rows 654001 to 654500...
# Fetching rows 654501 to 655000...
# Fetching rows 655001 to 655500...
# Fetching rows 655501 to 656000...
# Fetching rows 656001 to 656500...
# Fetching rows 656501 to 657000...
# Fetching rows 657001 to 657500...
# Fetching rows 657501 to 658000...
# Fetching rows 658001 to 658500...
# Fetching rows 658501 to 659000...
# Fetching rows 659001 to 659500...
# Fetching rows 659501 to 660000...
# Fetching rows 660001 to 660500...
# Saved intermediate dataset up to offset 660000.
# Fetching rows 660501 to 661000...
# Fetching rows 661001 to 661500...
# Fetching rows 661501 to 662000...
# Fetching rows 662001 to 662500...
# Fetching rows 662501 to 663000...
# Fetching rows 663001 to 663500...
# Fetching rows 663501 to 664000...
# Fetching rows 664001 to 664500...
# Fetching rows 664501 to 665000...
# Fetching rows 665001 to 665500...
# ...
# Fetching rows 794501 to 795000...
# Fetching rows 795001 to 795500...
# Fetching rows 795501 to 796000...
# Fetching rows 796001 to 796500...
# Fetching rows 796501 to 797000...
# Fetching rows 797001 to 797500...
# Fetching rows 797501 to 798000...
# Fetching rows 798001 to 798500...
# Fetching rows 798501 to 799000...
# Fetching rows 799001 to 799500...
# Fetching rows 799501 to 800000...
# Fetching rows 800001 to 800500...
# Saved intermediate dataset up to offset 800000.
# Fetching rows 800501 to 801000...
# Fetching rows 801001 to 801500...
# Fetching rows 801501 to 802000...
# Fetching rows 802001 to 802500...
# Fetching rows 802501 to 803000...
# Fetching rows 803001 to 803500...
# Fetching rows 803501 to 804000...
# Fetching rows 804001 to 804500...
# Fetching rows 804501 to 805000...
# Fetching rows 805001 to 805500...
# Fetching rows 805501 to 806000...
# Fetching rows 806001 to 806500...
# Fetching rows 806501 to 807000...
# Fetching rows 807001 to 807500...
# Fetching rows 807501 to 808000...
# Fetching rows 808001 to 808500...
# Fetching rows 808501 to 809000...
# Fetching rows 809001 to 809500...
# Fetching rows 809501 to 810000...
# Fetching rows 810001 to 810500...
# Saved intermediate dataset up to offset 810000.
# Fetching rows 810501 to 811000...
# Fetching rows 811001 to 811500...
# Fetching rows 811501 to 812000...
# Fetching rows 812001 to 812500...
# Fetching rows 812501 to 813000...
# Fetching rows 813001 to 813500...
# Fetching rows 813501 to 814000...
# Fetching rows 814001 to 814500...
# Fetching rows 814501 to 815000...
# Fetching rows 815001 to 815500...
# Fetching rows 815501 to 816000...
# Fetching rows 816001 to 816500...
# Fetching rows 816501 to 817000...
# Fetching rows 817001 to 817500...
# Fetching rows 817501 to 818000...
# Fetching rows 818001 to 818500...
# Fetching rows 818501 to 819000...
# Fetching rows 819001 to 819500...
# Fetching rows 819501 to 820000...
# Fetching rows 820001 to 820500...
# Saved intermediate dataset up to offset 820000.
# Fetching rows 820501 to 821000...
# Fetching rows 821001 to 821500...
# Fetching rows 821501 to 822000...
# Fetching rows 822001 to 822500...
# Fetching rows 822501 to 823000...
# Fetching rows 823001 to 823500...
# Fetching rows 823501 to 824000...
# Fetching rows 824001 to 824500...
# Fetching rows 824501 to 825000...
# Fetching rows 825001 to 825500...
# Fetching rows 825501 to 826000...
# Fetching rows 826001 to 826500...
# Fetching rows 826501 to 827000...
# Fetching rows 827001 to 827500...
# Fetching rows 827501 to 828000...
# Fetching rows 828001 to 828500...
# Fetching rows 828501 to 829000...
# Fetching rows 829001 to 829500...
# Fetching rows 829501 to 830000...
# Fetching rows 830001 to 830500...
# Saved intermediate dataset up to offset 830000.
# Fetching rows 830501 to 831000...
# Fetching rows 831001 to 831500...
# Fetching rows 831501 to 832000...
# Fetching rows 832001 to 832500...
# Fetching rows 832501 to 833000...
# Fetching rows 833001 to 833500...
# Fetching rows 833501 to 834000...
# Fetching rows 834001 to 834500...
# Fetching rows 834501 to 835000...
# Fetching rows 835001 to 835500...
# Fetching rows 835501 to 836000...
# Fetching rows 836001 to 836500...
# Fetching rows 836501 to 837000...
# Fetching rows 837001 to 837500...
# Fetching rows 837501 to 838000...
# Fetching rows 838001 to 838500...
# Fetching rows 838501 to 839000...
# Fetching rows 839001 to 839500...
# Fetching rows 839501 to 840000...
# Fetching rows 840001 to 840500...
# Saved intermediate dataset up to offset 840000.
# Fetching rows 840501 to 841000...
# Fetching rows 841001 to 841500...
# Fetching rows 841501 to 842000...
# Fetching rows 842001 to 842500...
# Fetching rows 842501 to 843000...
# Fetching rows 843001 to 843500...
# Fetching rows 843501 to 844000...
# Fetching rows 844001 to 844500...
# Fetching rows 844501 to 845000...
# Fetching rows 845001 to 845500...
# Fetching rows 845501 to 846000...
# Fetching rows 846001 to 846500...
# Fetching rows 846501 to 847000...
# Fetching rows 847001 to 847500...
# Fetching rows 847501 to 848000...
# Fetching rows 848001 to 848500...
# Fetching rows 848501 to 849000...
# Fetching rows 849001 to 849500...
# Fetching rows 849501 to 850000...
# Fetching rows 850001 to 850500...
# Saved intermediate dataset up to offset 850000.
# Fetching rows 850501 to 851000...
# Fetching rows 851001 to 851500...
# Fetching rows 851501 to 852000...
# Fetching rows 852001 to 852500...
# Fetching rows 852501 to 853000...
# Fetching rows 853001 to 853500...
# Fetching rows 853501 to 854000...
# Fetching rows 854001 to 854500...
# Fetching rows 854501 to 855000...
# Fetching rows 855001 to 855500...
# Fetching rows 855501 to 856000...
# Fetching rows 856001 to 856500...
# Fetching rows 856501 to 857000...
# Fetching rows 857001 to 857500...
# Fetching rows 857501 to 858000...
# Fetching rows 858001 to 858500...
# Fetching rows 858501 to 859000...
# Fetching rows 859001 to 859500...
# Fetching rows 859501 to 860000...
# Fetching rows 860001 to 860500...
# Saved intermediate dataset up to offset 860000.
# Fetching rows 860501 to 861000...
# Fetching rows 861001 to 861500...
# Fetching rows 861501 to 862000...
# Fetching rows 862001 to 862500...
# Fetching rows 862501 to 863000...
# Fetching rows 863001 to 863500...
# Fetching rows 863501 to 864000...
# Fetching rows 864001 to 864500...
# Fetching rows 864501 to 865000...
# Fetching rows 865001 to 865500...
# Fetching rows 865501 to 866000...
# Fetching rows 866001 to 866500...
# Fetching rows 866501 to 867000...
# Fetching rows 867001 to 867500...
# Fetching rows 867501 to 868000...
# Fetching rows 868001 to 868500...
# Fetching rows 868501 to 869000...
# Fetching rows 869001 to 869500...
# Fetching rows 869501 to 870000...
# Fetching rows 870001 to 870500...
# Saved intermediate dataset up to offset 870000.
# Fetching rows 870501 to 871000...
# Fetching rows 871001 to 871500...
# Fetching rows 871501 to 872000...
# Fetching rows 872001 to 872500...
# Fetching rows 872501 to 873000...
# Fetching rows 873001 to 873500...
# Fetching rows 873501 to 874000...
# Fetching rows 874001 to 874500...
# Fetching rows 874501 to 875000...
# Fetching rows 875001 to 875500...
# Fetching rows 875501 to 876000...
# Fetching rows 876001 to 876500...
# Fetching rows 876501 to 877000...
# Fetching rows 877001 to 877500...
# Fetching rows 877501 to 878000...
# Fetching rows 878001 to 878500...
# Fetching rows 878501 to 879000...
# Fetching rows 879001 to 879500...
# Fetching rows 879501 to 880000...
# Fetching rows 880001 to 880500...
# Saved intermediate dataset up to offset 880000.
# Fetching rows 880501 to 881000...
# Fetching rows 881001 to 881500...
# Fetching rows 881501 to 882000...
# Fetching rows 882001 to 882500...
# Fetching rows 882501 to 883000...
# Fetching rows 883001 to 883500...
# Fetching rows 883501 to 884000...
# Fetching rows 884001 to 884500...
# Fetching rows 884501 to 885000...
# Fetching rows 885001 to 885500...
# Fetching rows 885501 to 886000...
# Fetching rows 886001 to 886500...
# Fetching rows 886501 to 887000...
# Fetching rows 887001 to 887500...
# Fetching rows 887501 to 888000...
# Fetching rows 888001 to 888500...
# Fetching rows 888501 to 889000...
# Fetching rows 889001 to 889500...
# Fetching rows 889501 to 890000...
# Fetching rows 890001 to 890500...
# Saved intermediate dataset up to offset 890000.
# Fetching rows 890501 to 891000...
# Fetching rows 891001 to 891500...
# Fetching rows 891501 to 892000...
# Fetching rows 892001 to 892500...
# Fetching rows 892501 to 893000...
# Fetching rows 893001 to 893500...
# Fetching rows 893501 to 894000...
# Fetching rows 894001 to 894500...
# Fetching rows 894501 to 895000...
# Fetching rows 895001 to 895500...
# Fetching rows 895501 to 896000...
# Fetching rows 896001 to 896500...
# Fetching rows 896501 to 897000...
# Fetching rows 897001 to 897500...
# Fetching rows 897501 to 898000...
# Fetching rows 898001 to 898500...
# Fetching rows 898501 to 899000...
# Fetching rows 899001 to 899500...
# Fetching rows 899501 to 900000...
# Fetching rows 900001 to 900500...
# Saved intermediate dataset up to offset 900000.
# Fetching rows 900501 to 901000...
# Fetching rows 901001 to 901500...
# Fetching rows 901501 to 902000...
# Fetching rows 902001 to 902500...
# Fetching rows 902501 to 903000...
# Fetching rows 903001 to 903500...
# Fetching rows 903501 to 904000...
# Fetching rows 904001 to 904500...
# Fetching rows 904501 to 905000...
# Fetching rows 905001 to 905500...
# Fetching rows 905501 to 906000...
# Fetching rows 906001 to 906500...
# Fetching rows 906501 to 907000...
# Fetching rows 907001 to 907500...
# Fetching rows 907501 to 908000...
# Fetching rows 908001 to 908500...
# Fetching rows 908501 to 909000...
# Fetching rows 909001 to 909500...
# Fetching rows 909501 to 910000...
# Fetching rows 910001 to 910500...
# Saved intermediate dataset up to offset 910000.
# Fetching rows 910501 to 911000...
# Fetching rows 911001 to 911500...
# Fetching rows 911501 to 912000...
# Fetching rows 912001 to 912500...
# Fetching rows 912501 to 913000...
# Fetching rows 913001 to 913500...
# Fetching rows 913501 to 914000...
# Fetching rows 914001 to 914500...
# Fetching rows 914501 to 915000...
# Fetching rows 915001 to 915500...
# Fetching rows 915501 to 916000...
# Fetching rows 916001 to 916500...
# Fetching rows 916501 to 917000...
# Fetching rows 917001 to 917500...
# Fetching rows 917501 to 918000...
# Fetching rows 918001 to 918500...
# Fetching rows 918501 to 919000...
# Fetching rows 919001 to 919500...
# Fetching rows 919501 to 920000...
# Fetching rows 920001 to 920500...
# Saved intermediate dataset up to offset 920000.
# Fetching rows 920501 to 921000...
# Fetching rows 921001 to 921500...
# Fetching rows 921501 to 922000...
# Fetching rows 922001 to 922500...
# Fetching rows 922501 to 923000...
# Fetching rows 923001 to 923500...
# Fetching rows 923501 to 924000...
# Fetching rows 924001 to 924500...
# Fetching rows 924501 to 925000...
# Fetching rows 925001 to 925500...
# Fetching rows 925501 to 926000...
# Fetching rows 926001 to 926500...
# Fetching rows 926501 to 927000...
# Fetching rows 927001 to 927500...
# Fetching rows 927501 to 928000...
# Fetching rows 928001 to 928500...
# Fetching rows 928501 to 929000...
# Fetching rows 929001 to 929500...
# Fetching rows 929501 to 930000...
# Fetching rows 930001 to 930500...
# Saved intermediate dataset up to offset 930000.
# Fetching rows 930501 to 931000...
# Fetching rows 931001 to 931500...
# Fetching rows 931501 to 932000...
# Fetching rows 932001 to 932500...
# Fetching rows 932501 to 933000...
# Fetching rows 933001 to 933500...
# Fetching rows 933501 to 934000...
# Fetching rows 934001 to 934500...
# Fetching rows 934501 to 935000...
# Fetching rows 935001 to 935500...
# Fetching rows 935501 to 936000...
# Fetching rows 936001 to 936500...
# Fetching rows 936501 to 937000...
# Fetching rows 937001 to 937500...
# Fetching rows 937501 to 938000...
# Fetching rows 938001 to 938500...
# Fetching rows 938501 to 939000...
# Fetching rows 939001 to 939500...
# Fetching rows 939501 to 940000...
# Fetching rows 940001 to 940500...
# Saved intermediate dataset up to offset 940000.
# Fetching rows 940501 to 941000...
# Fetching rows 941001 to 941500...
# Fetching rows 941501 to 942000...
# Fetching rows 942001 to 942500...
# Fetching rows 942501 to 943000...
# Fetching rows 943001 to 943500...
# Fetching rows 943501 to 944000...
# Fetching rows 944001 to 944500...
# Fetching rows 944501 to 945000...
# Fetching rows 945001 to 945500...
# Fetching rows 945501 to 946000...
# Fetching rows 946001 to 946500...
# Fetching rows 946501 to 947000...
# Fetching rows 947001 to 947500...
# Fetching rows 947501 to 948000...
# Fetching rows 948001 to 948500...
# Fetching rows 948501 to 949000...
# Fetching rows 949001 to 949500...
# Fetching rows 949501 to 950000...
# Fetching rows 950001 to 950500...
# Saved intermediate dataset up to offset 950000.
# Fetching rows 950501 to 951000...
# Fetching rows 951001 to 951500...
# Fetching rows 951501 to 952000...
# Fetching rows 952001 to 952500...
# Fetching rows 952501 to 953000...
# Fetching rows 953001 to 953500...
# Fetching rows 953501 to 954000...
# Fetching rows 954001 to 954500...
# Fetching rows 954501 to 955000...
# Fetching rows 955001 to 955500...
# Fetching rows 955501 to 956000...
# Fetching rows 956001 to 956500...
# Fetching rows 956501 to 957000...
# Fetching rows 957001 to 957500...
# Fetching rows 957501 to 958000...
# Fetching rows 958001 to 958500...
# Fetching rows 958501 to 959000...
# Fetching rows 959001 to 959500...
# Fetching rows 959501 to 960000...
# Fetching rows 960001 to 960500...
# Saved intermediate dataset up to offset 960000.
# Fetching rows 960501 to 961000...
# Fetching rows 961001 to 961500...
# Fetching rows 961501 to 962000...
# Fetching rows 962001 to 962500...
# Fetching rows 962501 to 963000...
# Fetching rows 963001 to 963500...
# Fetching rows 963501 to 964000...
# Fetching rows 964001 to 964500...
# Fetching rows 964501 to 965000...
# Fetching rows 965001 to 965500...
# Fetching rows 965501 to 966000...
# Fetching rows 966001 to 966500...
# Fetching rows 966501 to 967000...
# Fetching rows 967001 to 967500...
# Fetching rows 967501 to 968000...
# Fetching rows 968001 to 968500...
# Fetching rows 968501 to 969000...
# Fetching rows 969001 to 969500...
# Fetching rows 969501 to 970000...
# Fetching rows 970001 to 970500...
# Saved intermediate dataset up to offset 970000.
# Fetching rows 970501 to 971000...
# Fetching rows 971001 to 971500...
# Fetching rows 971501 to 972000...
# Fetching rows 972001 to 972500...
# Fetching rows 972501 to 973000...
# Fetching rows 973001 to 973500...
# Fetching rows 973501 to 974000...
# Fetching rows 974001 to 974500...
# Fetching rows 974501 to 975000...
# Fetching rows 975001 to 975500...
# Fetching rows 975501 to 976000...
# Fetching rows 976001 to 976500...
# Fetching rows 976501 to 977000...
# Fetching rows 977001 to 977500...
# Fetching rows 977501 to 978000...
# Fetching rows 978001 to 978500...
# Fetching rows 978501 to 979000...
# Fetching rows 979001 to 979500...
# Fetching rows 979501 to 980000...
# Fetching rows 980001 to 980500...
# Saved intermediate dataset up to offset 980000.
# Fetching rows 980501 to 981000...
# Fetching rows 981001 to 981500...
# Fetching rows 981501 to 982000...
# Fetching rows 982001 to 982500...
# Fetching rows 982501 to 983000...
# Fetching rows 983001 to 983500...
# Fetching rows 983501 to 984000...
# Fetching rows 984001 to 984500...
# Fetching rows 984501 to 985000...
# Fetching rows 985001 to 985500...
# Fetching rows 985501 to 986000...
# Fetching rows 986001 to 986500...
# Fetching rows 986501 to 987000...
# Fetching rows 987001 to 987500...
# Fetching rows 987501 to 988000...
# Fetching rows 988001 to 988500...
# Fetching rows 988501 to 989000...
# Fetching rows 989001 to 989500...
# Fetching rows 989501 to 990000...
# Fetching rows 990001 to 990500...
# Saved intermediate dataset up to offset 990000.
# Fetching rows 990501 to 991000...
# Fetching rows 991001 to 991500...
# Fetching rows 991501 to 992000...
# Fetching rows 992001 to 992500...
# Fetching rows 992501 to 993000...
# Fetching rows 993001 to 993500...
# Fetching rows 993501 to 994000...
# Fetching rows 994001 to 994500...
# Fetching rows 994501 to 995000...
# Fetching rows 995001 to 995500...
# Fetching rows 995501 to 996000...
# Fetching rows 996001 to 996500...
# Fetching rows 996501 to 997000...
# Fetching rows 997001 to 997500...
# Fetching rows 997501 to 998000...
# Fetching rows 998001 to 998500...
# Fetching rows 998501 to 999000...
# Fetching rows 999001 to 999500...
# Fetching rows 999501 to 1000000...
# Dataset saved as electronic_devices_1M.csv
#                                               Device  \
# 0  http://dbpedia.org/resource/Casio_G'zOne_Commando
# 1         http://dbpedia.org/resource/Royole_FlexPai
# 2      http://dbpedia.org/resource/Samsung_Continuum
# 3  http://dbpedia.org/resource/Samsung_Galaxy_(or...
# 4     http://dbpedia.org/resource/Samsung_Galaxy_A01
#
#                                    Name  \
# 0                 Casio G'zOne Commando
# 1                        Royole FlexPai
# 2                Samsung Continuum i400
# 3  Samsung Galaxy (GT-I7500, GT-I7500L)
# 4                    Samsung Galaxy A01
#
#                                         Manufacturer Release Date
# 0  http://dbpedia.org/resource/NEC_Casio_Mobile_C...   2011-04-28
# 1                 http://dbpedia.org/resource/Royole   2018-01-08
# 2    http://dbpedia.org/resource/Samsung_Electronics   2010-06-04
# 3                http://dbpedia.org/resource/Samsung   2009-06-29
# 4    http://dbpedia.org/resource/Samsung_Electronics   2020-01-24

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# Set up the SPARQL endpoint
sparql = SPARQLWrapper("http://dbpedia.org/sparql")

# Initialize an empty list to store data
data = []

# Define query parameters
rows_per_query = 500  # Number of rows to fetch per query
total_records = 1000000  # Target total number of records

for offset in range(0, total_records, rows_per_query):
    # SPARQL query with pagination
    sparql.setQuery(f"""
        SELECT ?device ?name ?manufacturer ?releaseDate
        WHERE {{
            # ?device a dbo:Device .
            # ?device foaf:name ?name .
            OPTIONAL {{ ?device dbo:manufacturer ?manufacturer . }}
            OPTIONAL {{ ?device dbo:releaseDate ?releaseDate . }}
            FILTER (lang(?name) = 'en')
        }}
        LIMIT {rows_per_query} OFFSET {offset}
    """)
    sparql.setReturnFormat(JSON)

    try:
        # Execute the query
        results = sparql.query().convert()
        for result in results["results"]["bindings"]:
            # Append data to the list
            data.append({
                "Device": result["device"]["value"],
                "Name": result["name"]["value"],
                "Manufacturer": result.get("manufacturer", {}).get("value"),
                "Release Date": result.get("releaseDate", {}).get("value"),
            })
    except Exception as e:
        print(f"Error occurred for offset {offset}: {e}")
        break

# Convert the collected data to a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv("electronic_devices_1M.csv", index=False)
print("Dataset saved as electronic_devices_1M.csv")

# Display the first few rows
print(df.head())
# Out:
# Dataset saved as electronic_devices_1M.csv
#                                               Device  \
# 0  http://dbpedia.org/resource/Casio_G'zOne_Commando
# 1         http://dbpedia.org/resource/Royole_FlexPai
# 2      http://dbpedia.org/resource/Samsung_Continuum
# 3  http://dbpedia.org/resource/Samsung_Galaxy_(or...
# 4     http://dbpedia.org/resource/Samsung_Galaxy_A01
#
#                                    Name  \
# 0                 Casio G'zOne Commando
# 1                        Royole FlexPai
# 2                Samsung Continuum i400
# 3  Samsung Galaxy (GT-I7500, GT-I7500L)
# 4                    Samsung Galaxy A01
#
#                                         Manufacturer Release Date
# 0  http://dbpedia.org/resource/NEC_Casio_Mobile_C...   2011-04-28
# 1                 http://dbpedia.org/resource/Royole   2018-01-08
# 2    http://dbpedia.org/resource/Samsung_Electronics   2010-06-04
# 3                http://dbpedia.org/resource/Samsung   2009-06-29
# 4    http://dbpedia.org/resource/Samsung_Electronics   2020-01-24
